# %%
import warnings
warnings .filterwarnings('ignore')

# improting the librarires

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from word2number import w2n
from tqdm import tqdm

# %%
cars= pd.read_csv("CarPrice_Data.csv")

# %%
cars.head(10)
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
# 5       6          2                  audi fox      gas        std        two
# 6       7          1                audi 100ls      gas        std       four
# 7       8          1                 audi 5000      gas        std       four
# 8       9          1                 audi 4000      gas      turbo       four
# 9      10          0       audi 5000s (diesel)      gas      turbo        two
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3          NaN        fwd          front       99.8  ...         109
# 4          NaN        4wd          front       99.4  ...         136
# 5        sedan        fwd          front       99.8  ...         136
# 6        sedan        fwd          front      105.8  ...         136
# 7        wagon        fwd          front      105.8  ...         136
# 8        sedan        fwd          front      105.8  ...         131
# 9    hatchback        4wd          front       99.5  ...         131
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
# 5        mpfi       3.19    3.40              8.5        110     5500      19
# 6        mpfi       3.19    3.40              8.5        110     5500      19
# 7        mpfi       3.19    3.40              8.5        110     5500      19
# 8        mpfi       3.13    3.40              8.3        140     5500      17
# 9        mpfi       3.13    3.40              7.0        160     5500      16
#
#    highwaympg      price
# 0          27  13495.000
# 1          27  16500.000
# 2          26  16500.000
# 3          30  13950.000
# 4          22  17450.000
# 5          25  15250.000
# 6          25  17710.000
# 7          25  18920.000
# 8          20  23875.000
# 9          22  17859.167
#
# [10 rows x 26 columns]

# %%
cars.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
cars.shape
# Out:
# (205, 26)

# %%
cars.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          194 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           200 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    193 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
cars.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
list(cars.columns)
# Out:
# ['car_ID',
#  'symboling',
#  'CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'wheelbase',
#  'carlength',
#  'carwidth',
#  'carheight',
#  'curbweight',
#  'enginetype',
#  'cylindernumber',
#  'enginesize',
#  'fuelsystem',
#  'boreratio',
#  'stroke',
#  'compressionratio',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg',
#  'price']

# %%
for x in cars.columns:
    print(x)
# Out:
# car_ID
# symboling
# CarName
# fueltype
# aspiration
# doornumber
# carbody
# drivewheel
# enginelocation
# wheelbase
# carlength
# carwidth
# carheight
# curbweight
# enginetype
# cylindernumber
# enginesize
# fuelsystem
# boreratio
# stroke
# compressionratio
# horsepower
# peakrpm
# citympg
# highwaympg
# price

# %%
cars.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# citympg           205.0     25.219512     6.542142    13.00    19.00
# highwaympg        205.0     30.751220     6.886443    16.00    25.00
# price             205.0  13276.710571  7988.852332  5118.00  7788.00
#
#                        50%       75%       max
# car_ID              103.00    154.00    205.00
# symboling             1.00      2.00      3.00
# wheelbase            97.00    102.40    120.90
# carlength           173.20    183.10    208.10
# carwidth             65.50     66.90     72.30
# carheight            54.10     55.50     59.80
# curbweight         2414.00   2935.00   4066.00
# enginesize          120.00    141.00    326.00
# boreratio             3.31      3.58      3.94
# stroke                3.29      3.41      4.17
# compressionratio      9.00      9.40     23.00
# horsepower           95.00    116.00    288.00
# peakrpm            5200.00   5500.00   6600.00
# citympg              24.00     30.00     49.00
# highwaympg           30.00     34.00     54.00
# price             10295.00  16503.00  45400.00

# %%
cars.describe(include="object").T
# Out:
#                count unique            top freq
# CarName          205    147  toyota corona    6
# fueltype         194      2            gas  174
# aspiration       205      2            std  168
# doornumber       205      2           four  115
# carbody          200      5          sedan   91
# drivewheel       205      3            fwd  120
# enginelocation   193      2          front  190
# enginetype       205      7            ohc  148
# cylindernumber   205      7           four  159
# fuelsystem       205      8           mpfi   94

# %%
list(cars.columns[cars.dtypes == 'int64'])
# Out:
# ['car_ID',
#  'symboling',
#  'curbweight',
#  'enginesize',
#  'horsepower',
#  'peakrpm',
#  'citympg',
#  'highwaympg']

# %%
cars.iloc[0:5,0:4]
# Out:
#    car_ID  symboling                   CarName fueltype
# 0       1          3        alfa-romero giulia      gas
# 1       2          3       alfa-romero stelvio      gas
# 2       3          1  alfa-romero Quadrifoglio      gas
# 3       4          2               audi 100 ls      gas
# 4       5          2                audi 100ls      gas

# %%
cars.iloc[0:5]
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3          NaN        fwd          front       99.8  ...         109
# 4          NaN        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
cars.loc[0:5,['CarName','fueltype']]
# Out:
#                     CarName fueltype
# 0        alfa-romero giulia      gas
# 1       alfa-romero stelvio      gas
# 2  alfa-romero Quadrifoglio      gas
# 3               audi 100 ls      gas
# 4                audi 100ls      gas
# 5                  audi fox      gas

# %%
cars['fueltype'].unique()
# Out:
# array(['gas', nan, 'diesel'], dtype=object)

# %%
cars['fueltype'].dtype
# Out:
# dtype('O')

# %%
cars['fueltype'].value_counts()
# Out:
# fueltype
# gas       174
# diesel     20
# Name: count, dtype: int64

# %%
cars.isnull().sum()
# Out:
# car_ID               0
# symboling            0
# CarName              0
# fueltype            11
# aspiration           0
# doornumber           0
# carbody              5
# drivewheel           0
# enginelocation      12
# wheelbase            0
# carlength            0
# carwidth             0
# carheight            0
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize           0
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %%
cars_copy= cars.copy()

# %%
null_columns=cars.columns[cars.isnull().any()]
cars[null_columns].isnull().sum()*100/len(cars)
# Out:
# fueltype          5.365854
# carbody           2.439024
# enginelocation    5.853659
# dtype: float64

# %%
list(null_columns)
# Out:
# ['fueltype', 'carbody', 'enginelocation']

# %%
for x in cars.columns[cars.isnull().any()]:
    print('---------------')
    print('coulmn name',x)
    print('---------------')
    print(cars[x].value_counts()*100/len(cars))
    print(cars[x].value_counts())
# Out:
# ---------------
# coulmn name fueltype
# ---------------
# fueltype
# gas       84.878049
# diesel     9.756098
# Name: count, dtype: float64
# fueltype
# gas       174
# diesel     20
# Name: count, dtype: int64
# ---------------
# coulmn name carbody
# ---------------
# carbody
# sedan          44.390244
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: count, dtype: float64
# carbody
# sedan          91
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
# ---------------
# coulmn name enginelocation
# ---------------
# enginelocation
# front    92.682927
# rear      1.463415
# Name: count, dtype: float64
# enginelocation
# front    190
# rear       3
# Name: count, dtype: int64

# %%
cars['fueltype'].fillna (value='gas',inplace=True)
cars['enginelocation'].fillna (value='front',inplace=True)

# %%
cars['fueltype'].unique()
# Out:
# array(['gas', 'diesel'], dtype=object)

# %%
cars['enginelocation'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
for x in cars.columns:
    print('---------------')
    print('coulmn name',x)
    print('---------------')
    print(cars[x].value_counts()*100/len(cars))
    print(cars[x].value_counts())
# Out:
# ---------------
# coulmn name car_ID
# ---------------
# car_ID
# 1      0.487805
# 142    0.487805
# 132    0.487805
# 133    0.487805
# 134    0.487805
#          ...
# 72     0.487805
# 73     0.487805
# 74     0.487805
# 75     0.487805
# 205    0.487805
# Name: count, Length: 205, dtype: float64
# car_ID
# 1      1
# 142    1
# 132    1
# 133    1
# 134    1
#       ..
# 72     1
# 73     1
# 74     1
# 75     1
# 205    1
# Name: count, Length: 205, dtype: int64
# ---------------
# coulmn name symboling
# ---------------
# symboling
#  0    32.682927
#  1    26.341463
#  2    15.609756
#  3    13.170732
# -1    10.731707
# -2     1.463415
# Name: count, dtype: float64
# symboling
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: count, dtype: int64
# ---------------
# coulmn name CarName
# ---------------
# CarName
# toyota corona           2.926829
# toyota corolla          2.926829
# peugeot 504             2.926829
# subaru dl               1.951220
# mitsubishi mirage g4    1.463415
#                           ...
# mazda glc 4             0.487805
# mazda rx2 coupe         0.487805
# maxda glc deluxe        0.487805
# maxda rx3               0.487805
# volvo 246               0.487805
# Name: count, Length: 147, dtype: float64
# CarName
# toyota corona           6
# toyota corolla          6
# peugeot 504             6
# subaru dl               4
# mitsubishi mirage g4    3
#                        ..
# mazda glc 4             1
# mazda rx2 coupe         1
# maxda glc deluxe        1
# maxda rx3               1
# volvo 246               1
# Name: count, Length: 147, dtype: int64
# ---------------
# coulmn name fueltype
# ---------------
# fueltype
# gas       90.243902
# diesel     9.756098
# Name: count, dtype: float64
# fueltype
# gas       185
# diesel     20
# Name: count, dtype: int64
# ---------------
# coulmn name aspiration
# ---------------
# aspiration
# std      81.95122
# turbo    18.04878
# Name: count, dtype: float64
# aspiration
# std      168
# turbo     37
# Name: count, dtype: int64
# ---------------
# coulmn name doornumber
# ---------------
# doornumber
# four    56.097561
# two     43.902439
# Name: count, dtype: float64
# doornumber
# four    115
# two      90
# Name: count, dtype: int64
# ---------------
# coulmn name carbody
# ---------------
# carbody
# sedan          44.390244
# hatchback      34.146341
# wagon          12.195122
# hardtop         3.902439
# convertible     2.926829
# Name: count, dtype: float64
# carbody
# sedan          91
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64
# ---------------
# coulmn name drivewheel
# ---------------
# drivewheel
# fwd    58.536585
# rwd    37.073171
# 4wd     4.390244
# Name: count, dtype: float64
# drivewheel
# fwd    120
# rwd     76
# 4wd      9
# Name: count, dtype: int64
# ---------------
# coulmn name enginelocation
# ---------------
# enginelocation
# front    98.536585
# rear      1.463415
# Name: count, dtype: float64
# enginelocation
# front    202
# rear       3
# Name: count, dtype: int64
# ---------------
# coulmn name wheelbase
# ---------------
# wheelbase
# 94.5     10.243902
# 93.7      9.756098
# 95.7      6.341463
# 96.5      3.902439
# 97.3      3.414634
# 98.4      3.414634
# 104.3     2.926829
# 100.4     2.926829
# 107.9     2.926829
# 98.8      2.926829
# 99.1      2.926829
# 96.3      2.926829
# 109.1     2.439024
# 93.1      2.439024
# 97.2      2.439024
# 95.9      2.439024
# 102.4     2.439024
# 97.0      1.951220
# 95.3      1.951220
# 114.2     1.951220
# 101.2     1.951220
# 110.0     1.463415
# 103.5     1.463415
# 89.5      1.463415
# 105.8     1.463415
# 96.1      0.975610
# 102.9     0.975610
# 104.5     0.975610
# 91.3      0.975610
# 96.9      0.975610
# 88.6      0.975610
# 113.0     0.975610
# 99.8      0.975610
# 115.6     0.975610
# 103.3     0.975610
# 86.6      0.975610
# 104.9     0.975610
# 93.3      0.487805
# 99.4      0.487805
# 99.5      0.487805
# 88.4      0.487805
# 94.3      0.487805
# 96.0      0.487805
# 95.1      0.487805
# 93.0      0.487805
# 102.0     0.487805
# 106.7     0.487805
# 108.0     0.487805
# 96.6      0.487805
# 99.2      0.487805
# 112.0     0.487805
# 102.7     0.487805
# 120.9     0.487805
# Name: count, dtype: float64
# wheelbase
# 94.5     21
# 93.7     20
# 95.7     13
# 96.5      8
# 97.3      7
# 98.4      7
# 104.3     6
# 100.4     6
# 107.9     6
# 98.8      6
# 99.1      6
# 96.3      6
# 109.1     5
# 93.1      5
# 97.2      5
# 95.9      5
# 102.4     5
# 97.0      4
# 95.3      4
# 114.2     4
# 101.2     4
# 110.0     3
# 103.5     3
# 89.5      3
# 105.8     3
# 96.1      2
# 102.9     2
# 104.5     2
# 91.3      2
# 96.9      2
# 88.6      2
# 113.0     2
# 99.8      2
# 115.6     2
# 103.3     2
# 86.6      2
# 104.9     2
# 93.3      1
# 99.4      1
# 99.5      1
# 88.4      1
# 94.3      1
# 96.0      1
# 95.1      1
# 93.0      1
# 102.0     1
# 106.7     1
# 108.0     1
# 96.6      1
# 99.2      1
# 112.0     1
# 102.7     1
# 120.9     1
# Name: count, dtype: int64
# ---------------
# coulmn name carlength
# ---------------
# carlength
# 157.3    7.317073
# 188.8    5.365854
# 171.7    3.414634
# 186.7    3.414634
# 166.3    3.414634
#            ...
# 165.6    0.487805
# 187.5    0.487805
# 180.3    0.487805
# 208.1    0.487805
# 199.2    0.487805
# Name: count, Length: 75, dtype: float64
# carlength
# 157.3    15
# 188.8    11
# 171.7     7
# 186.7     7
# 166.3     7
#          ..
# 165.6     1
# 187.5     1
# 180.3     1
# 208.1     1
# 199.2     1
# Name: count, Length: 75, dtype: int64
# ---------------
# coulmn name carwidth
# ---------------
# carwidth
# 63.8    11.707317
# 66.5    11.219512
# 65.4     7.317073
# 63.6     5.365854
# 64.4     4.878049
# 68.4     4.878049
# 64.0     4.390244
# 65.5     3.902439
# 65.2     3.414634
# 64.2     2.926829
# 66.3     2.926829
# 65.6     2.926829
# 67.2     2.926829
# 67.9     2.439024
# 66.9     2.439024
# 65.7     1.951220
# 68.9     1.951220
# 64.8     1.951220
# 63.9     1.463415
# 70.3     1.463415
# 71.7     1.463415
# 71.4     1.463415
# 65.0     1.463415
# 68.3     0.975610
# 67.7     0.975610
# 64.1     0.975610
# 66.1     0.975610
# 69.6     0.975610
# 64.6     0.975610
# 72.0     0.487805
# 68.0     0.487805
# 70.5     0.487805
# 61.8     0.487805
# 66.0     0.487805
# 62.5     0.487805
# 70.6     0.487805
# 72.3     0.487805
# 66.6     0.487805
# 63.4     0.487805
# 60.3     0.487805
# 70.9     0.487805
# 66.4     0.487805
# 66.2     0.487805
# 68.8     0.487805
# Name: count, dtype: float64
# carwidth
# 63.8    24
# 66.5    23
# 65.4    15
# 63.6    11
# 64.4    10
# 68.4    10
# 64.0     9
# 65.5     8
# 65.2     7
# 64.2     6
# 66.3     6
# 65.6     6
# 67.2     6
# 67.9     5
# 66.9     5
# 65.7     4
# 68.9     4
# 64.8     4
# 63.9     3
# 70.3     3
# 71.7     3
# 71.4     3
# 65.0     3
# 68.3     2
# 67.7     2
# 64.1     2
# 66.1     2
# 69.6     2
# 64.6     2
# 72.0     1
# 68.0     1
# 70.5     1
# 61.8     1
# 66.0     1
# 62.5     1
# 70.6     1
# 72.3     1
# 66.6     1
# 63.4     1
# 60.3     1
# 70.9     1
# 66.4     1
# 66.2     1
# 68.8     1
# Name: count, dtype: int64
# ---------------
# coulmn name carheight
# ---------------
# carheight
# 50.8    6.829268
# 52.0    5.853659
# 55.7    5.853659
# 54.1    4.878049
# 54.5    4.878049
# 55.5    4.390244
# 56.7    3.902439
# 54.3    3.902439
# 52.6    3.414634
# 56.1    3.414634
# 51.6    3.414634
# 53.0    2.926829
# 52.8    2.926829
# 54.9    2.926829
# 50.2    2.926829
# 53.7    2.439024
# 55.1    2.439024
# 50.6    2.439024
# 49.6    1.951220
# 58.7    1.951220
# 53.3    1.951220
# 52.5    1.463415
# 59.1    1.463415
# 56.2    1.463415
# 49.7    1.463415
# 57.5    1.463415
# 53.5    1.463415
# 54.4    0.975610
# 53.9    0.975610
# 56.3    0.975610
# 50.5    0.975610
# 59.8    0.975610
# 56.5    0.975610
# 54.7    0.975610
# 48.8    0.975610
# 49.4    0.975610
# 51.4    0.975610
# 51.0    0.487805
# 54.8    0.487805
# 55.4    0.487805
# 56.0    0.487805
# 55.2    0.487805
# 53.2    0.487805
# 47.8    0.487805
# 55.9    0.487805
# 52.4    0.487805
# 55.6    0.487805
# 53.1    0.487805
# 58.3    0.487805
# Name: count, dtype: float64
# carheight
# 50.8    14
# 52.0    12
# 55.7    12
# 54.1    10
# 54.5    10
# 55.5     9
# 56.7     8
# 54.3     8
# 52.6     7
# 56.1     7
# 51.6     7
# 53.0     6
# 52.8     6
# 54.9     6
# 50.2     6
# 53.7     5
# 55.1     5
# 50.6     5
# 49.6     4
# 58.7     4
# 53.3     4
# 52.5     3
# 59.1     3
# 56.2     3
# 49.7     3
# 57.5     3
# 53.5     3
# 54.4     2
# 53.9     2
# 56.3     2
# 50.5     2
# 59.8     2
# 56.5     2
# 54.7     2
# 48.8     2
# 49.4     2
# 51.4     2
# 51.0     1
# 54.8     1
# 55.4     1
# 56.0     1
# 55.2     1
# 53.2     1
# 47.8     1
# 55.9     1
# 52.4     1
# 55.6     1
# 53.1     1
# 58.3     1
# Name: count, dtype: int64
# ---------------
# coulmn name curbweight
# ---------------
# curbweight
# 2385    1.951220
# 1918    1.463415
# 2275    1.463415
# 1989    1.463415
# 2410    0.975610
#           ...
# 2370    0.487805
# 2328    0.487805
# 2833    0.487805
# 2921    0.487805
# 3062    0.487805
# Name: count, Length: 171, dtype: float64
# curbweight
# 2385    4
# 1918    3
# 2275    3
# 1989    3
# 2410    2
#        ..
# 2370    1
# 2328    1
# 2833    1
# 2921    1
# 3062    1
# Name: count, Length: 171, dtype: int64
# ---------------
# coulmn name enginetype
# ---------------
# enginetype
# ohc      72.195122
# ohcf      7.317073
# ohcv      6.341463
# dohc      5.853659
# l         5.853659
# rotor     1.951220
# dohcv     0.487805
# Name: count, dtype: float64
# enginetype
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: count, dtype: int64
# ---------------
# coulmn name cylindernumber
# ---------------
# cylindernumber
# four      77.560976
# six       11.707317
# five       5.365854
# eight      2.439024
# two        1.951220
# three      0.487805
# twelve     0.487805
# Name: count, dtype: float64
# cylindernumber
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: count, dtype: int64
# ---------------
# coulmn name enginesize
# ---------------
# enginesize
# 122    7.317073
# 92     7.317073
# 97     6.829268
# 98     6.829268
# 108    6.341463
# 90     5.853659
# 110    5.853659
# 109    3.902439
# 120    3.414634
# 141    3.414634
# 152    2.926829
# 181    2.926829
# 146    2.926829
# 121    2.926829
# 156    2.439024
# 136    2.439024
# 91     2.439024
# 183    1.951220
# 130    1.951220
# 171    1.463415
# 70     1.463415
# 194    1.463415
# 209    1.463415
# 164    1.463415
# 258    0.975610
# 140    0.975610
# 134    0.975610
# 234    0.975610
# 132    0.975610
# 131    0.975610
# 173    0.487805
# 203    0.487805
# 161    0.487805
# 80     0.487805
# 151    0.487805
# 103    0.487805
# 304    0.487805
# 308    0.487805
# 326    0.487805
# 119    0.487805
# 111    0.487805
# 79     0.487805
# 61     0.487805
# 145    0.487805
# Name: count, dtype: float64
# enginesize
# 122    15
# 92     15
# 97     14
# 98     14
# 108    13
# 90     12
# 110    12
# 109     8
# 120     7
# 141     7
# 152     6
# 181     6
# 146     6
# 121     6
# 156     5
# 136     5
# 91      5
# 183     4
# 130     4
# 171     3
# 70      3
# 194     3
# 209     3
# 164     3
# 258     2
# 140     2
# 134     2
# 234     2
# 132     2
# 131     2
# 173     1
# 203     1
# 161     1
# 80      1
# 151     1
# 103     1
# 304     1
# 308     1
# 326     1
# 119     1
# 111     1
# 79      1
# 61      1
# 145     1
# Name: count, dtype: int64
# ---------------
# coulmn name fuelsystem
# ---------------
# fuelsystem
# mpfi    45.853659
# 2bbl    32.195122
# idi      9.756098
# 1bbl     5.365854
# spdi     4.390244
# 4bbl     1.463415
# mfi      0.487805
# spfi     0.487805
# Name: count, dtype: float64
# fuelsystem
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: count, dtype: int64
# ---------------
# coulmn name boreratio
# ---------------
# boreratio
# 3.62    11.219512
# 3.19     9.756098
# 3.15     7.317073
# 3.03     5.853659
# 2.97     5.853659
# 3.46     4.390244
# 3.31     3.902439
# 3.43     3.902439
# 3.78     3.902439
# 3.27     3.414634
# 2.91     3.414634
# 3.58     2.926829
# 3.39     2.926829
# 3.33     2.926829
# 3.05     2.926829
# 3.54     2.926829
# 3.70     2.439024
# 3.01     2.439024
# 3.35     1.951220
# 3.17     1.463415
# 3.59     1.463415
# 3.74     1.463415
# 3.47     0.975610
# 3.94     0.975610
# 3.24     0.975610
# 3.63     0.975610
# 3.13     0.975610
# 3.80     0.975610
# 3.50     0.975610
# 2.54     0.487805
# 3.08     0.487805
# 3.61     0.487805
# 3.34     0.487805
# 2.68     0.487805
# 3.60     0.487805
# 2.92     0.487805
# 3.76     0.487805
# 2.99     0.487805
# Name: count, dtype: float64
# boreratio
# 3.62    23
# 3.19    20
# 3.15    15
# 3.03    12
# 2.97    12
# 3.46     9
# 3.31     8
# 3.43     8
# 3.78     8
# 3.27     7
# 2.91     7
# 3.58     6
# 3.39     6
# 3.33     6
# 3.05     6
# 3.54     6
# 3.70     5
# 3.01     5
# 3.35     4
# 3.17     3
# 3.59     3
# 3.74     3
# 3.47     2
# 3.94     2
# 3.24     2
# 3.63     2
# 3.13     2
# 3.80     2
# 3.50     2
# 2.54     1
# 3.08     1
# 3.61     1
# 3.34     1
# 2.68     1
# 3.60     1
# 2.92     1
# 3.76     1
# 2.99     1
# Name: count, dtype: int64
# ---------------
# coulmn name stroke
# ---------------
# stroke
# 3.400    9.756098
# 3.230    6.829268
# 3.150    6.829268
# 3.030    6.829268
# 3.390    6.341463
# 2.640    5.365854
# 3.290    4.390244
# 3.350    4.390244
# 3.460    3.902439
# 3.110    2.926829
# 3.270    2.926829
# 3.410    2.926829
# 3.070    2.926829
# 3.580    2.926829
# 3.190    2.926829
# 3.500    2.926829
# 3.640    2.439024
# 3.520    2.439024
# 3.860    1.951220
# 3.540    1.951220
# 3.470    1.951220
# 3.255    1.951220
# 3.900    1.463415
# 2.900    1.463415
# 3.100    0.975610
# 4.170    0.975610
# 2.800    0.975610
# 2.190    0.975610
# 3.080    0.975610
# 2.680    0.975610
# 2.360    0.487805
# 3.160    0.487805
# 2.070    0.487805
# 3.210    0.487805
# 3.120    0.487805
# 2.760    0.487805
# 2.870    0.487805
# Name: count, dtype: float64
# stroke
# 3.400    20
# 3.230    14
# 3.150    14
# 3.030    14
# 3.390    13
# 2.640    11
# 3.290     9
# 3.350     9
# 3.460     8
# 3.110     6
# 3.270     6
# 3.410     6
# 3.070     6
# 3.580     6
# 3.190     6
# 3.500     6
# 3.640     5
# 3.520     5
# 3.860     4
# 3.540     4
# 3.470     4
# 3.255     4
# 3.900     3
# 2.900     3
# 3.100     2
# 4.170     2
# 2.800     2
# 2.190     2
# 3.080     2
# 2.680     2
# 2.360     1
# 3.160     1
# 2.070     1
# 3.210     1
# 3.120     1
# 2.760     1
# 2.870     1
# Name: count, dtype: int64
# ---------------
# coulmn name compressionratio
# ---------------
# compressionratio
# 9.00     22.439024
# 9.40     12.682927
# 8.50      6.829268
# 9.50      6.341463
# 9.30      5.365854
# 8.70      4.390244
# 8.00      3.902439
# 9.20      3.902439
# 7.00      3.414634
# 8.60      2.439024
# 21.00     2.439024
# 8.40      2.439024
# 7.50      2.439024
# 23.00     2.439024
# 9.60      2.439024
# 21.50     1.951220
# 7.60      1.951220
# 10.00     1.463415
# 22.50     1.463415
# 8.30      1.463415
# 8.80      1.463415
# 7.70      0.975610
# 8.10      0.975610
# 9.10      0.487805
# 9.31      0.487805
# 7.80      0.487805
# 9.41      0.487805
# 21.90     0.487805
# 22.00     0.487805
# 22.70     0.487805
# 10.10     0.487805
# 11.50     0.487805
# Name: count, dtype: float64
# compressionratio
# 9.00     46
# 9.40     26
# 8.50     14
# 9.50     13
# 9.30     11
# 8.70      9
# 8.00      8
# 9.20      8
# 7.00      7
# 8.60      5
# 21.00     5
# 8.40      5
# 7.50      5
# 23.00     5
# 9.60      5
# 21.50     4
# 7.60      4
# 10.00     3
# 22.50     3
# 8.30      3
# 8.80      3
# 7.70      2
# 8.10      2
# 9.10      1
# 9.31      1
# 7.80      1
# 9.41      1
# 21.90     1
# 22.00     1
# 22.70     1
# 10.10     1
# 11.50     1
# Name: count, dtype: int64
# ---------------
# coulmn name horsepower
# ---------------
# horsepower
# 68     9.268293
# 70     5.365854
# 69     4.878049
# 116    4.390244
# 110    3.902439
# 95     3.414634
# 114    2.926829
# 160    2.926829
# 101    2.926829
# 62     2.926829
# 88     2.926829
# 145    2.439024
# 76     2.439024
# 97     2.439024
# 84     2.439024
# 90     2.439024
# 82     2.439024
# 102    2.439024
# 92     1.951220
# 111    1.951220
# 123    1.951220
# 86     1.951220
# 207    1.463415
# 73     1.463415
# 182    1.463415
# 121    1.463415
# 85     1.463415
# 152    1.463415
# 176    0.975610
# 94     0.975610
# 56     0.975610
# 112    0.975610
# 161    0.975610
# 184    0.975610
# 155    0.975610
# 156    0.975610
# 52     0.975610
# 100    0.975610
# 162    0.975610
# 140    0.487805
# 115    0.487805
# 134    0.487805
# 78     0.487805
# 142    0.487805
# 288    0.487805
# 143    0.487805
# 48     0.487805
# 200    0.487805
# 58     0.487805
# 55     0.487805
# 60     0.487805
# 175    0.487805
# 154    0.487805
# 72     0.487805
# 120    0.487805
# 64     0.487805
# 135    0.487805
# 262    0.487805
# 106    0.487805
# Name: count, dtype: float64
# horsepower
# 68     19
# 70     11
# 69     10
# 116     9
# 110     8
# 95      7
# 114     6
# 160     6
# 101     6
# 62      6
# 88      6
# 145     5
# 76      5
# 97      5
# 84      5
# 90      5
# 82      5
# 102     5
# 92      4
# 111     4
# 123     4
# 86      4
# 207     3
# 73      3
# 182     3
# 121     3
# 85      3
# 152     3
# 176     2
# 94      2
# 56      2
# 112     2
# 161     2
# 184     2
# 155     2
# 156     2
# 52      2
# 100     2
# 162     2
# 140     1
# 115     1
# 134     1
# 78      1
# 142     1
# 288     1
# 143     1
# 48      1
# 200     1
# 58      1
# 55      1
# 60      1
# 175     1
# 154     1
# 72      1
# 120     1
# 64      1
# 135     1
# 262     1
# 106     1
# Name: count, dtype: int64
# ---------------
# coulmn name peakrpm
# ---------------
# peakrpm
# 5500    18.048780
# 4800    17.560976
# 5000    13.170732
# 5200    11.219512
# 5400     6.341463
# 6000     4.390244
# 4500     3.414634
# 5800     3.414634
# 5250     3.414634
# 5100     2.439024
# 4150     2.439024
# 4200     2.439024
# 4350     1.951220
# 4750     1.951220
# 5900     1.463415
# 4250     1.463415
# 4400     1.463415
# 6600     0.975610
# 4650     0.487805
# 5600     0.487805
# 5750     0.487805
# 4900     0.487805
# 5300     0.487805
# Name: count, dtype: float64
# peakrpm
# 5500    37
# 4800    36
# 5000    27
# 5200    23
# 5400    13
# 6000     9
# 4500     7
# 5800     7
# 5250     7
# 5100     5
# 4150     5
# 4200     5
# 4350     4
# 4750     4
# 5900     3
# 4250     3
# 4400     3
# 6600     2
# 4650     1
# 5600     1
# 5750     1
# 4900     1
# 5300     1
# Name: count, dtype: int64
# ---------------
# coulmn name citympg
# ---------------
# citympg
# 31    13.658537
# 19    13.170732
# 24    10.731707
# 27     6.829268
# 17     6.341463
# 26     5.853659
# 23     5.853659
# 21     3.902439
# 25     3.902439
# 30     3.902439
# 38     3.414634
# 28     3.414634
# 16     2.926829
# 37     2.926829
# 22     1.951220
# 29     1.463415
# 15     1.463415
# 20     1.463415
# 18     1.463415
# 14     0.975610
# 34     0.487805
# 35     0.487805
# 32     0.487805
# 36     0.487805
# 45     0.487805
# 13     0.487805
# 49     0.487805
# 47     0.487805
# 33     0.487805
# Name: count, dtype: float64
# citympg
# 31    28
# 19    27
# 24    22
# 27    14
# 17    13
# 26    12
# 23    12
# 21     8
# 25     8
# 30     8
# 38     7
# 28     7
# 16     6
# 37     6
# 22     4
# 29     3
# 15     3
# 20     3
# 18     3
# 14     2
# 34     1
# 35     1
# 32     1
# 36     1
# 45     1
# 13     1
# 49     1
# 47     1
# 33     1
# Name: count, dtype: int64
# ---------------
# coulmn name highwaympg
# ---------------
# highwaympg
# 25    9.268293
# 38    8.292683
# 24    8.292683
# 30    7.804878
# 32    7.804878
# 34    6.829268
# 37    6.341463
# 28    6.341463
# 29    4.878049
# 33    4.390244
# 22    3.902439
# 31    3.902439
# 23    3.414634
# 27    2.439024
# 43    1.951220
# 42    1.463415
# 26    1.463415
# 41    1.463415
# 19    0.975610
# 39    0.975610
# 18    0.975610
# 16    0.975610
# 20    0.975610
# 36    0.975610
# 47    0.975610
# 46    0.975610
# 54    0.487805
# 17    0.487805
# 53    0.487805
# 50    0.487805
# Name: count, dtype: float64
# highwaympg
# 25    19
# 38    17
# 24    17
# 30    16
# 32    16
# 34    14
# 37    13
# 28    13
# 29    10
# 33     9
# 22     8
# 31     8
# 23     7
# 27     5
# 43     4
# 42     3
# 26     3
# 41     3
# 19     2
# 39     2
# 18     2
# 16     2
# 20     2
# 36     2
# 47     2
# 46     2
# 54     1
# 17     1
# 53     1
# 50     1
# Name: count, dtype: int64
# ---------------
# coulmn name price
# ---------------
# price
# 8921.0     0.975610
# 9279.0     0.975610
# 7898.0     0.975610
# 8916.5     0.975610
# 7775.0     0.975610
#              ...
# 45400.0    0.487805
# 16503.0    0.487805
# 5389.0     0.487805
# 6189.0     0.487805
# 22625.0    0.487805
# Name: count, Length: 189, dtype: float64
# price
# 8921.0     2
# 9279.0     2
# 7898.0     2
# 8916.5     2
# 7775.0     2
#           ..
# 45400.0    1
# 16503.0    1
# 5389.0     1
# 6189.0     1
# 22625.0    1
# Name: count, Length: 189, dtype: int64

# %%
cars.loc[cars['carbody'].isnull()]
# Out:
#     car_ID  symboling      CarName fueltype aspiration doornumber carbody  \
# 3        4          2  audi 100 ls      gas        std       four     NaN
# 4        5          2   audi 100ls      gas        std       four     NaN
# 13      14          0       bmw x3      gas        std       four     NaN
# 14      15          1       bmw z4      gas        std       four     NaN
# 41      42          0  honda civic      gas        std       four     NaN
#
#    drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 3         fwd          front       99.8  ...         109        mpfi
# 4         4wd          front       99.4  ...         136        mpfi
# 13        rwd          front      101.2  ...         164        mpfi
# 14        rwd          front      103.5  ...         164        mpfi
# 41        fwd          front       96.5  ...         110        mpfi
#
#     boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 3        3.19    3.40             10.0        102     5500      24
# 4        3.19    3.40              8.0        115     5500      18
# 13       3.31    3.19              9.0        121     4250      21
# 14       3.31    3.19              9.0        121     4250      20
# 41       3.15    3.58              9.0        101     5800      24
#
#     highwaympg    price
# 3           30  13950.0
# 4           22  17450.0
# 13          28  21105.0
# 14          25  24565.0
# 41          28  12945.0
#
# [5 rows x 26 columns]

# %%
cars['carbody'] = np.where(
   (cars['CarName'] =='audi 100 ls') & (cars['carbody'].isnull()) , 'sedan', cars['carbody'])

# %%
cars['carbody'] = np.where(
   (cars['CarName'] =='audi 100ls') & (cars['carbody'].isnull()) , 'sedan', cars['carbody'])

# %%
cars['carbody'].fillna (value='sedan', inplace = True)

# %%
pd.set_option('display.max_rows',20000, 'display.max_columns',100)

# %%
cars['CarName'].value_counts().sort_index(ascending=True)
# Out:
# CarName
# Nissan versa                       1
# alfa-romero Quadrifoglio           1
# alfa-romero giulia                 1
# alfa-romero stelvio                1
# audi 100 ls                        1
# audi 100ls                         2
# audi 4000                          1
# audi 5000                          1
# audi 5000s (diesel)                1
# audi fox                           1
# bmw 320i                           2
# bmw x1                             1
# bmw x3                             2
# bmw x4                             1
# bmw x5                             1
# bmw z4                             1
# buick century                      1
# buick century luxus (sw)           1
# buick century special              1
# buick electra 225 custom           1
# buick opel isuzu deluxe            1
# buick regal sport coupe (turbo)    1
# buick skyhawk                      1
# buick skylark                      1
# chevrolet impala                   1
# chevrolet monte carlo              1
# chevrolet vega 2300                1
# dodge challenger se                1
# dodge colt (sw)                    1
# dodge colt hardtop                 1
# dodge coronet custom               1
# dodge coronet custom (sw)          1
# dodge d200                         1
# dodge dart custom                  1
# dodge monaco (sw)                  1
# dodge rampage                      1
# honda accord                       2
# honda accord cvcc                  1
# honda accord lx                    1
# honda civic                        3
# honda civic (auto)                 1
# honda civic 1300                   1
# honda civic 1500 gl                1
# honda civic cvcc                   2
# honda prelude                      1
# isuzu D-Max                        2
# isuzu D-Max V-Cross                1
# isuzu MU-X                         1
# jaguar xf                          1
# jaguar xj                          1
# jaguar xk                          1
# maxda glc deluxe                   1
# maxda rx3                          1
# mazda 626                          3
# mazda glc                          2
# mazda glc 4                        1
# mazda glc custom                   1
# mazda glc custom l                 1
# mazda glc deluxe                   2
# mazda rx-4                         2
# mazda rx-7 gs                      2
# mazda rx2 coupe                    1
# mercury cougar                     1
# mitsubishi g4                      3
# mitsubishi lancer                  1
# mitsubishi mirage                  1
# mitsubishi mirage g4               3
# mitsubishi montero                 1
# mitsubishi outlander               3
# mitsubishi pajero                  1
# nissan clipper                     2
# nissan dayz                        1
# nissan fuga                        1
# nissan gt-r                        1
# nissan juke                        1
# nissan kicks                       1
# nissan latio                       2
# nissan leaf                        1
# nissan note                        1
# nissan nv200                       1
# nissan otti                        1
# nissan rogue                       2
# nissan teana                       1
# nissan titan                       1
# peugeot 304                        1
# peugeot 504                        6
# peugeot 504 (sw)                   1
# peugeot 505s turbo diesel          1
# peugeot 604sl                      2
# plymouth cricket                   1
# plymouth duster                    1
# plymouth fury gran sedan           1
# plymouth fury iii                  2
# plymouth satellite custom (sw)     1
# plymouth valiant                   1
# porcshce panamera                  1
# porsche boxter                     1
# porsche cayenne                    2
# porsche macan                      1
# renault 12tl                       1
# renault 5 gtl                      1
# saab 99e                           2
# saab 99gle                         2
# saab 99le                          2
# subaru                             2
# subaru baja                        1
# subaru brz                         1
# subaru dl                          4
# subaru r1                          1
# subaru r2                          1
# subaru trezia                      1
# subaru tribeca                     1
# toyota carina                      1
# toyota celica gt                   1
# toyota celica gt liftback          1
# toyota corolla                     6
# toyota corolla 1200                2
# toyota corolla 1600 (sw)           1
# toyota corolla liftback            2
# toyota corolla tercel              1
# toyota corona                      6
# toyota corona hardtop              1
# toyota corona liftback             1
# toyota corona mark ii              1
# toyota cressida                    1
# toyota mark ii                     3
# toyota starlet                     2
# toyota tercel                      1
# toyouta tercel                     1
# vokswagen rabbit                   1
# volkswagen 1131 deluxe sedan       1
# volkswagen 411 (sw)                1
# volkswagen dasher                  2
# volkswagen model 111               1
# volkswagen rabbit                  1
# volkswagen rabbit custom           1
# volkswagen super beetle            1
# volkswagen type 3                  1
# volvo 144ea                        2
# volvo 145e (sw)                    2
# volvo 244dl                        2
# volvo 245                          1
# volvo 246                          1
# volvo 264gl                        2
# volvo diesel                       1
# vw dasher                          1
# vw rabbit                          1
# Name: count, dtype: int64

# %%
cars['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
cars["CarName"] = np.where(cars["CarName"] == "vw dasher", "volkswagen dasher", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "vw rabbit", "volkswagen rabbit", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "vokswagen rabbit", "volkswagen rabbit", cars["CarName"])

cars["CarName"] = np.where(cars["CarName"] == "toyouta tercel", "toyota tercel", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "toyota corona", "toyota corolla", cars["CarName"])

cars["CarName"] = np.where(cars["CarName"] == "toyota corona hardtop", "toyota corolla hardtop", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "toyota corona liftback", "toyota corolla liftback", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "toyota corona mark ii", "toyota corolla mark ii", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "maxda glc deluxe", "mazda glc deluxe", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "maxda rx3", "mazda rx3", cars["CarName"])

cars["CarName"] = np.where(cars["CarName"] == "audi 100 ls", "audi 100ls", cars["CarName"])
cars["CarName"] = np.where(cars["CarName"] == "porcshce panamera", "porsche panamera", cars["CarName"])

# %%
CompanyName = cars['CarName'].apply(lambda x : x.split(' ')[0])

cars.insert(3,"CompanyName",CompanyName)

# %%
cars.drop(['car_ID'],axis=1,inplace=True)

# %%
cars
# Out:
#      symboling                          CarName  CompanyName fueltype  \
# 0            3               alfa-romero giulia  alfa-romero      gas
# 1            3              alfa-romero stelvio  alfa-romero      gas
# 2            1         alfa-romero Quadrifoglio  alfa-romero      gas
# 3            2                       audi 100ls         audi      gas
# 4            2                       audi 100ls         audi      gas
# 5            2                         audi fox         audi      gas
# 6            1                       audi 100ls         audi      gas
# 7            1                        audi 5000         audi      gas
# 8            1                        audi 4000         audi      gas
# 9            0              audi 5000s (diesel)         audi      gas
# 10           2                         bmw 320i          bmw      gas
# 11           0                         bmw 320i          bmw      gas
# 12           0                           bmw x1          bmw      gas
# 13           0                           bmw x3          bmw      gas
# 14           1                           bmw z4          bmw      gas
# 15           0                           bmw x4          bmw      gas
# 16           0                           bmw x5          bmw      gas
# 17           0                           bmw x3          bmw      gas
# 18           2                 chevrolet impala    chevrolet      gas
# 19           1            chevrolet monte carlo    chevrolet      gas
# 20           0              chevrolet vega 2300    chevrolet      gas
# 21           1                    dodge rampage        dodge      gas
# 22           1              dodge challenger se        dodge      gas
# 23           1                       dodge d200        dodge      gas
# 24           1                dodge monaco (sw)        dodge      gas
# 25           1               dodge colt hardtop        dodge      gas
# 26           1                  dodge colt (sw)        dodge      gas
# 27           1             dodge coronet custom        dodge      gas
# 28          -1                dodge dart custom        dodge      gas
# 29           3        dodge coronet custom (sw)        dodge      gas
# 30           2                      honda civic        honda      gas
# 31           2                 honda civic cvcc        honda      gas
# 32           1                      honda civic        honda      gas
# 33           1                honda accord cvcc        honda      gas
# 34           1                 honda civic cvcc        honda      gas
# 35           0                  honda accord lx        honda      gas
# 36           0              honda civic 1500 gl        honda      gas
# 37           0                     honda accord        honda      gas
# 38           0                 honda civic 1300        honda      gas
# 39           0                    honda prelude        honda      gas
# 40           0                     honda accord        honda      gas
# 41           0                      honda civic        honda      gas
# 42           1               honda civic (auto)        honda      gas
# 43           0                       isuzu MU-X        isuzu      gas
# 44           1                     isuzu D-Max         isuzu      gas
# 45           0              isuzu D-Max V-Cross        isuzu      gas
# 46           2                     isuzu D-Max         isuzu      gas
# 47           0                        jaguar xj       jaguar      gas
# 48           0                        jaguar xf       jaguar      gas
# 49           0                        jaguar xk       jaguar      gas
# 50           1                        mazda rx3        mazda      gas
# 51           1                 mazda glc deluxe        mazda      gas
# 52           1                  mazda rx2 coupe        mazda      gas
# 53           1                       mazda rx-4        mazda      gas
# 54           1                 mazda glc deluxe        mazda      gas
# 55           3                        mazda 626        mazda      gas
# 56           3                        mazda glc        mazda      gas
# 57           3                    mazda rx-7 gs        mazda      gas
# 58           3                      mazda glc 4        mazda      gas
# 59           1                        mazda 626        mazda      gas
# 60           0               mazda glc custom l        mazda      gas
# 61           1                 mazda glc custom        mazda      gas
# 62           0                       mazda rx-4        mazda      gas
# 63           0                 mazda glc deluxe        mazda   diesel
# 64           0                        mazda 626        mazda      gas
# 65           0                        mazda glc        mazda      gas
# 66           0                    mazda rx-7 gs        mazda   diesel
# 67          -1         buick electra 225 custom        buick   diesel
# 68          -1         buick century luxus (sw)        buick   diesel
# 69           0                    buick century        buick   diesel
# 70          -1                    buick skyhawk        buick   diesel
# 71          -1          buick opel isuzu deluxe        buick      gas
# 72           3                    buick skylark        buick      gas
# 73           0            buick century special        buick      gas
# 74           1  buick regal sport coupe (turbo)        buick      gas
# 75           1                   mercury cougar      mercury      gas
# 76           2                mitsubishi mirage   mitsubishi      gas
# 77           2                mitsubishi lancer   mitsubishi      gas
# 78           2             mitsubishi outlander   mitsubishi      gas
# 79           1                    mitsubishi g4   mitsubishi      gas
# 80           3             mitsubishi mirage g4   mitsubishi      gas
# 81           3                    mitsubishi g4   mitsubishi      gas
# 82           3             mitsubishi outlander   mitsubishi      gas
# 83           3                    mitsubishi g4   mitsubishi      gas
# 84           3             mitsubishi mirage g4   mitsubishi      gas
# 85           1               mitsubishi montero   mitsubishi      gas
# 86           1                mitsubishi pajero   mitsubishi      gas
# 87           1             mitsubishi outlander   mitsubishi      gas
# 88          -1             mitsubishi mirage g4   mitsubishi      gas
# 89           1                     Nissan versa       Nissan      gas
# 90           1                      nissan gt-r       nissan   diesel
# 91           1                     nissan rogue       nissan      gas
# 92           1                     nissan latio       nissan      gas
# 93           1                     nissan titan       nissan      gas
# 94           1                      nissan leaf       nissan      gas
# 95           1                      nissan juke       nissan      gas
# 96           1                     nissan latio       nissan      gas
# 97           1                      nissan note       nissan      gas
# 98           2                   nissan clipper       nissan      gas
# 99           0                     nissan rogue       nissan      gas
# 100          0                     nissan nv200       nissan      gas
# 101          0                      nissan dayz       nissan      gas
# 102          0                      nissan fuga       nissan      gas
# 103          0                      nissan otti       nissan      gas
# 104          3                     nissan teana       nissan      gas
# 105          3                     nissan kicks       nissan      gas
# 106          1                   nissan clipper       nissan      gas
# 107          0                      peugeot 504      peugeot      gas
# 108          0                      peugeot 304      peugeot   diesel
# 109          0                 peugeot 504 (sw)      peugeot      gas
# 110          0                      peugeot 504      peugeot   diesel
# 111          0                      peugeot 504      peugeot      gas
# 112          0                    peugeot 604sl      peugeot   diesel
# 113          0                      peugeot 504      peugeot      gas
# 114          0        peugeot 505s turbo diesel      peugeot   diesel
# 115          0                      peugeot 504      peugeot      gas
# 116          0                      peugeot 504      peugeot   diesel
# 117          0                    peugeot 604sl      peugeot      gas
# 118          1                plymouth fury iii     plymouth      gas
# 119          1                 plymouth cricket     plymouth      gas
# 120          1                plymouth fury iii     plymouth      gas
# 121          1   plymouth satellite custom (sw)     plymouth      gas
# 122          1         plymouth fury gran sedan     plymouth      gas
# 123         -1                 plymouth valiant     plymouth      gas
# 124          3                  plymouth duster     plymouth      gas
# 125          3                    porsche macan      porsche      gas
# 126          3                 porsche panamera      porsche      gas
# 127          3                  porsche cayenne      porsche      gas
# 128          3                   porsche boxter      porsche      gas
# 129          1                  porsche cayenne      porsche      gas
# 130          0                     renault 12tl      renault      gas
# 131          2                    renault 5 gtl      renault      gas
# 132          3                         saab 99e         saab      gas
# 133          2                        saab 99le         saab      gas
# 134          3                        saab 99le         saab      gas
# 135          2                       saab 99gle         saab      gas
# 136          3                       saab 99gle         saab      gas
# 137          2                         saab 99e         saab      gas
# 138          2                           subaru       subaru      gas
# 139          2                        subaru dl       subaru      gas
# 140          2                        subaru dl       subaru      gas
# 141          0                           subaru       subaru      gas
# 142          0                       subaru brz       subaru      gas
# 143          0                      subaru baja       subaru      gas
# 144          0                        subaru r1       subaru      gas
# 145          0                        subaru r2       subaru      gas
# 146          0                    subaru trezia       subaru      gas
# 147          0                   subaru tribeca       subaru      gas
# 148          0                        subaru dl       subaru      gas
# 149          0                        subaru dl       subaru      gas
# 150          1           toyota corolla mark ii       toyota      gas
# 151          1                   toyota corolla       toyota      gas
# 152          1              toyota corolla 1200       toyota      gas
# 153          0           toyota corolla hardtop       toyota      gas
# 154          0         toyota corolla 1600 (sw)       toyota      gas
# 155          0                    toyota carina       toyota      gas
# 156          0                   toyota mark ii       toyota      gas
# 157          0              toyota corolla 1200       toyota      gas
# 158          0                   toyota corolla       toyota   diesel
# 159          0                   toyota corolla       toyota   diesel
# 160          0                   toyota corolla       toyota      gas
# 161          0                   toyota corolla       toyota      gas
# 162          0                   toyota mark ii       toyota      gas
# 163          1          toyota corolla liftback       toyota      gas
# 164          1                   toyota corolla       toyota      gas
# 165          1        toyota celica gt liftback       toyota      gas
# 166          1            toyota corolla tercel       toyota      gas
# 167          2          toyota corolla liftback       toyota      gas
# 168          2                   toyota corolla       toyota      gas
# 169          2                   toyota starlet       toyota      gas
# 170          2                    toyota tercel       toyota      gas
# 171          2                   toyota corolla       toyota      gas
# 172          2                  toyota cressida       toyota      gas
# 173         -1                   toyota corolla       toyota      gas
# 174         -1                 toyota celica gt       toyota   diesel
# 175         -1                   toyota corolla       toyota      gas
# 176         -1                   toyota corolla       toyota      gas
# 177         -1                   toyota mark ii       toyota      gas
# 178          3          toyota corolla liftback       toyota      gas
# 179          3                   toyota corolla       toyota      gas
# 180         -1                   toyota starlet       toyota      gas
# 181         -1                    toyota tercel       toyota      gas
# 182          2                volkswagen rabbit   volkswagen   diesel
# 183          2     volkswagen 1131 deluxe sedan   volkswagen      gas
# 184          2             volkswagen model 111   volkswagen   diesel
# 185          2                volkswagen type 3   volkswagen      gas
# 186          2              volkswagen 411 (sw)   volkswagen      gas
# 187          2          volkswagen super beetle   volkswagen   diesel
# 188          2                volkswagen dasher   volkswagen      gas
# 189          3                volkswagen dasher   volkswagen      gas
# 190          3                volkswagen rabbit   volkswagen      gas
# 191          0                volkswagen rabbit   volkswagen      gas
# 192          0         volkswagen rabbit custom   volkswagen   diesel
# 193          0                volkswagen dasher   volkswagen      gas
# 194         -2                  volvo 145e (sw)        volvo      gas
# 195         -1                      volvo 144ea        volvo      gas
# 196         -2                      volvo 244dl        volvo      gas
# 197         -1                        volvo 245        volvo      gas
# 198         -2                      volvo 264gl        volvo      gas
# 199         -1                     volvo diesel        volvo      gas
# 200         -1                  volvo 145e (sw)        volvo      gas
# 201         -1                      volvo 144ea        volvo      gas
# 202         -1                      volvo 244dl        volvo      gas
# 203         -1                        volvo 246        volvo   diesel
# 204         -1                      volvo 264gl        volvo      gas
#
#     aspiration doornumber      carbody drivewheel enginelocation  wheelbase  \
# 0          std        two  convertible        rwd          front       88.6
# 1          std        two  convertible        rwd          front       88.6
# 2          std        two    hatchback        rwd          front       94.5
# 3          std       four        sedan        fwd          front       99.8
# 4          std       four        sedan        4wd          front       99.4
# 5          std        two        sedan        fwd          front       99.8
# 6          std       four        sedan        fwd          front      105.8
# 7          std       four        wagon        fwd          front      105.8
# 8        turbo       four        sedan        fwd          front      105.8
# 9        turbo        two    hatchback        4wd          front       99.5
# 10         std        two        sedan        rwd          front      101.2
# 11         std       four        sedan        rwd          front      101.2
# 12         std        two        sedan        rwd          front      101.2
# 13         std       four        sedan        rwd          front      101.2
# 14         std       four        sedan        rwd          front      103.5
# 15         std       four        sedan        rwd          front      103.5
# 16         std        two        sedan        rwd          front      103.5
# 17         std       four        sedan        rwd          front      110.0
# 18         std        two    hatchback        fwd          front       88.4
# 19         std        two    hatchback        fwd          front       94.5
# 20         std       four        sedan        fwd          front       94.5
# 21         std        two    hatchback        fwd          front       93.7
# 22         std        two    hatchback        fwd          front       93.7
# 23       turbo        two    hatchback        fwd          front       93.7
# 24         std       four    hatchback        fwd          front       93.7
# 25         std       four        sedan        fwd          front       93.7
# 26         std       four        sedan        fwd          front       93.7
# 27       turbo        two        sedan        fwd          front       93.7
# 28         std       four        wagon        fwd          front      103.3
# 29       turbo        two    hatchback        fwd          front       95.9
# 30         std        two    hatchback        fwd          front       86.6
# 31         std        two    hatchback        fwd          front       86.6
# 32         std        two    hatchback        fwd          front       93.7
# 33         std        two    hatchback        fwd          front       93.7
# 34         std        two    hatchback        fwd          front       93.7
# 35         std       four        sedan        fwd          front       96.5
# 36         std       four        wagon        fwd          front       96.5
# 37         std        two    hatchback        fwd          front       96.5
# 38         std        two    hatchback        fwd          front       96.5
# 39         std       four        sedan        fwd          front       96.5
# 40         std       four        sedan        fwd          front       96.5
# 41         std       four        sedan        fwd          front       96.5
# 42         std        two        sedan        fwd          front       96.5
# 43         std       four        sedan        rwd          front       94.3
# 44         std        two        sedan        fwd          front       94.5
# 45         std       four        sedan        fwd          front       94.5
# 46         std        two    hatchback        rwd          front       96.0
# 47         std       four        sedan        rwd          front      113.0
# 48         std       four        sedan        rwd          front      113.0
# 49         std        two        sedan        rwd          front      102.0
# 50         std        two    hatchback        fwd          front       93.1
# 51         std        two    hatchback        fwd          front       93.1
# 52         std        two    hatchback        fwd          front       93.1
# 53         std       four        sedan        fwd          front       93.1
# 54         std       four        sedan        fwd          front       93.1
# 55         std        two    hatchback        rwd          front       95.3
# 56         std        two    hatchback        rwd          front       95.3
# 57         std        two    hatchback        rwd          front       95.3
# 58         std        two    hatchback        rwd          front       95.3
# 59         std        two    hatchback        fwd          front       98.8
# 60         std       four        sedan        fwd          front       98.8
# 61         std        two    hatchback        fwd          front       98.8
# 62         std       four        sedan        fwd          front       98.8
# 63         std       four        sedan        fwd          front       98.8
# 64         std       four    hatchback        fwd          front       98.8
# 65         std       four        sedan        rwd          front      104.9
# 66         std       four        sedan        rwd          front      104.9
# 67       turbo       four        sedan        rwd          front      110.0
# 68       turbo       four        wagon        rwd          front      110.0
# 69       turbo        two      hardtop        rwd          front      106.7
# 70       turbo       four        sedan        rwd          front      115.6
# 71         std       four        sedan        rwd          front      115.6
# 72         std        two  convertible        rwd          front       96.6
# 73         std       four        sedan        rwd          front      120.9
# 74         std        two      hardtop        rwd          front      112.0
# 75       turbo        two    hatchback        rwd          front      102.7
# 76         std        two    hatchback        fwd          front       93.7
# 77         std        two    hatchback        fwd          front       93.7
# 78         std        two    hatchback        fwd          front       93.7
# 79       turbo        two    hatchback        fwd          front       93.0
# 80       turbo        two    hatchback        fwd          front       96.3
# 81         std        two    hatchback        fwd          front       96.3
# 82       turbo        two    hatchback        fwd          front       95.9
# 83       turbo        two    hatchback        fwd          front       95.9
# 84       turbo        two    hatchback        fwd          front       95.9
# 85         std       four        sedan        fwd          front       96.3
# 86         std       four        sedan        fwd          front       96.3
# 87       turbo       four        sedan        fwd          front       96.3
# 88         std       four        sedan        fwd          front       96.3
# 89         std        two        sedan        fwd          front       94.5
# 90         std        two        sedan        fwd          front       94.5
# 91         std        two        sedan        fwd          front       94.5
# 92         std       four        sedan        fwd          front       94.5
# 93         std       four        wagon        fwd          front       94.5
# 94         std        two        sedan        fwd          front       94.5
# 95         std        two    hatchback        fwd          front       94.5
# 96         std       four        sedan        fwd          front       94.5
# 97         std       four        wagon        fwd          front       94.5
# 98         std        two      hardtop        fwd          front       95.1
# 99         std       four    hatchback        fwd          front       97.2
# 100        std       four        sedan        fwd          front       97.2
# 101        std       four        sedan        fwd          front      100.4
# 102        std       four        wagon        fwd          front      100.4
# 103        std       four        sedan        fwd          front      100.4
# 104        std        two    hatchback        rwd          front       91.3
# 105      turbo        two    hatchback        rwd          front       91.3
# 106        std        two    hatchback        rwd          front       99.2
# 107        std       four        sedan        rwd          front      107.9
# 108      turbo       four        sedan        rwd          front      107.9
# 109        std       four        wagon        rwd          front      114.2
# 110      turbo       four        wagon        rwd          front      114.2
# 111        std       four        sedan        rwd          front      107.9
# 112      turbo       four        sedan        rwd          front      107.9
# 113        std       four        wagon        rwd          front      114.2
# 114      turbo       four        wagon        rwd          front      114.2
# 115        std       four        sedan        rwd          front      107.9
# 116      turbo       four        sedan        rwd          front      107.9
# 117      turbo       four        sedan        rwd          front      108.0
# 118        std        two    hatchback        fwd          front       93.7
# 119      turbo        two    hatchback        fwd          front       93.7
# 120        std       four    hatchback        fwd          front       93.7
# 121        std       four        sedan        fwd          front       93.7
# 122        std       four        sedan        fwd          front       93.7
# 123        std       four        wagon        fwd          front      103.3
# 124      turbo        two    hatchback        rwd          front       95.9
# 125        std        two    hatchback        rwd          front       94.5
# 126        std        two      hardtop        rwd           rear       89.5
# 127        std        two      hardtop        rwd           rear       89.5
# 128        std        two  convertible        rwd           rear       89.5
# 129        std        two    hatchback        rwd          front       98.4
# 130        std       four        wagon        fwd          front       96.1
# 131        std        two    hatchback        fwd          front       96.1
# 132        std        two    hatchback        fwd          front       99.1
# 133        std       four        sedan        fwd          front       99.1
# 134        std        two    hatchback        fwd          front       99.1
# 135        std       four        sedan        fwd          front       99.1
# 136      turbo        two    hatchback        fwd          front       99.1
# 137      turbo       four        sedan        fwd          front       99.1
# 138        std        two    hatchback        fwd          front       93.7
# 139        std        two    hatchback        fwd          front       93.7
# 140        std        two    hatchback        4wd          front       93.3
# 141        std       four        sedan        fwd          front       97.2
# 142        std       four        sedan        fwd          front       97.2
# 143        std       four        sedan        fwd          front       97.2
# 144        std       four        sedan        4wd          front       97.0
# 145      turbo       four        sedan        4wd          front       97.0
# 146        std       four        wagon        fwd          front       97.0
# 147        std       four        wagon        fwd          front       97.0
# 148        std       four        wagon        4wd          front       96.9
# 149      turbo       four        wagon        4wd          front       96.9
# 150        std        two    hatchback        fwd          front       95.7
# 151        std        two    hatchback        fwd          front       95.7
# 152        std       four    hatchback        fwd          front       95.7
# 153        std       four        wagon        fwd          front       95.7
# 154        std       four        wagon        4wd          front       95.7
# 155        std       four        wagon        4wd          front       95.7
# 156        std       four        sedan        fwd          front       95.7
# 157        std       four    hatchback        fwd          front       95.7
# 158        std       four        sedan        fwd          front       95.7
# 159        std       four    hatchback        fwd          front       95.7
# 160        std       four        sedan        fwd          front       95.7
# 161        std       four    hatchback        fwd          front       95.7
# 162        std       four        sedan        fwd          front       95.7
# 163        std        two        sedan        rwd          front       94.5
# 164        std        two    hatchback        rwd          front       94.5
# 165        std        two        sedan        rwd          front       94.5
# 166        std        two    hatchback        rwd          front       94.5
# 167        std        two      hardtop        rwd          front       98.4
# 168        std        two      hardtop        rwd          front       98.4
# 169        std        two    hatchback        rwd          front       98.4
# 170        std        two      hardtop        rwd          front       98.4
# 171        std        two    hatchback        rwd          front       98.4
# 172        std        two  convertible        rwd          front       98.4
# 173        std       four        sedan        fwd          front      102.4
# 174      turbo       four        sedan        fwd          front      102.4
# 175        std       four    hatchback        fwd          front      102.4
# 176        std       four        sedan        fwd          front      102.4
# 177        std       four    hatchback        fwd          front      102.4
# 178        std        two    hatchback        rwd          front      102.9
# 179        std        two    hatchback        rwd          front      102.9
# 180        std       four        sedan        rwd          front      104.5
# 181        std       four        wagon        rwd          front      104.5
# 182        std        two        sedan        fwd          front       97.3
# 183        std        two        sedan        fwd          front       97.3
# 184        std       four        sedan        fwd          front       97.3
# 185        std       four        sedan        fwd          front       97.3
# 186        std       four        sedan        fwd          front       97.3
# 187      turbo       four        sedan        fwd          front       97.3
# 188        std       four        sedan        fwd          front       97.3
# 189        std        two  convertible        fwd          front       94.5
# 190        std        two    hatchback        fwd          front       94.5
# 191        std       four        sedan        fwd          front      100.4
# 192      turbo       four        sedan        fwd          front      100.4
# 193        std       four        wagon        fwd          front      100.4
# 194        std       four        sedan        rwd          front      104.3
# 195        std       four        wagon        rwd          front      104.3
# 196        std       four        sedan        rwd          front      104.3
# 197        std       four        wagon        rwd          front      104.3
# 198      turbo       four        sedan        rwd          front      104.3
# 199      turbo       four        wagon        rwd          front      104.3
# 200        std       four        sedan        rwd          front      109.1
# 201      turbo       four        sedan        rwd          front      109.1
# 202        std       four        sedan        rwd          front      109.1
# 203      turbo       four        sedan        rwd          front      109.1
# 204      turbo       four        sedan        rwd          front      109.1
#
#      carlength  carwidth  carheight  curbweight enginetype cylindernumber  \
# 0        168.8      64.1       48.8        2548       dohc           four
# 1        168.8      64.1       48.8        2548       dohc           four
# 2        171.2      65.5       52.4        2823       ohcv            six
# 3        176.6      66.2       54.3        2337        ohc           four
# 4        176.6      66.4       54.3        2824        ohc           five
# 5        177.3      66.3       53.1        2507        ohc           five
# 6        192.7      71.4       55.7        2844        ohc           five
# 7        192.7      71.4       55.7        2954        ohc           five
# 8        192.7      71.4       55.9        3086        ohc           five
# 9        178.2      67.9       52.0        3053        ohc           five
# 10       176.8      64.8       54.3        2395        ohc           four
# 11       176.8      64.8       54.3        2395        ohc           four
# 12       176.8      64.8       54.3        2710        ohc            six
# 13       176.8      64.8       54.3        2765        ohc            six
# 14       189.0      66.9       55.7        3055        ohc            six
# 15       189.0      66.9       55.7        3230        ohc            six
# 16       193.8      67.9       53.7        3380        ohc            six
# 17       197.0      70.9       56.3        3505        ohc            six
# 18       141.1      60.3       53.2        1488          l          three
# 19       155.9      63.6       52.0        1874        ohc           four
# 20       158.8      63.6       52.0        1909        ohc           four
# 21       157.3      63.8       50.8        1876        ohc           four
# 22       157.3      63.8       50.8        1876        ohc           four
# 23       157.3      63.8       50.8        2128        ohc           four
# 24       157.3      63.8       50.6        1967        ohc           four
# 25       157.3      63.8       50.6        1989        ohc           four
# 26       157.3      63.8       50.6        1989        ohc           four
# 27       157.3      63.8       50.6        2191        ohc           four
# 28       174.6      64.6       59.8        2535        ohc           four
# 29       173.2      66.3       50.2        2811        ohc           four
# 30       144.6      63.9       50.8        1713        ohc           four
# 31       144.6      63.9       50.8        1819        ohc           four
# 32       150.0      64.0       52.6        1837        ohc           four
# 33       150.0      64.0       52.6        1940        ohc           four
# 34       150.0      64.0       52.6        1956        ohc           four
# 35       163.4      64.0       54.5        2010        ohc           four
# 36       157.1      63.9       58.3        2024        ohc           four
# 37       167.5      65.2       53.3        2236        ohc           four
# 38       167.5      65.2       53.3        2289        ohc           four
# 39       175.4      65.2       54.1        2304        ohc           four
# 40       175.4      62.5       54.1        2372        ohc           four
# 41       175.4      65.2       54.1        2465        ohc           four
# 42       169.1      66.0       51.0        2293        ohc           four
# 43       170.7      61.8       53.5        2337        ohc           four
# 44       155.9      63.6       52.0        1874        ohc           four
# 45       155.9      63.6       52.0        1909        ohc           four
# 46       172.6      65.2       51.4        2734        ohc           four
# 47       199.6      69.6       52.8        4066       dohc            six
# 48       199.6      69.6       52.8        4066       dohc            six
# 49       191.7      70.6       47.8        3950       ohcv         twelve
# 50       159.1      64.2       54.1        1890        ohc           four
# 51       159.1      64.2       54.1        1900        ohc           four
# 52       159.1      64.2       54.1        1905        ohc           four
# 53       166.8      64.2       54.1        1945        ohc           four
# 54       166.8      64.2       54.1        1950        ohc           four
# 55       169.0      65.7       49.6        2380      rotor            two
# 56       169.0      65.7       49.6        2380      rotor            two
# 57       169.0      65.7       49.6        2385      rotor            two
# 58       169.0      65.7       49.6        2500      rotor            two
# 59       177.8      66.5       53.7        2385        ohc           four
# 60       177.8      66.5       55.5        2410        ohc           four
# 61       177.8      66.5       53.7        2385        ohc           four
# 62       177.8      66.5       55.5        2410        ohc           four
# 63       177.8      66.5       55.5        2443        ohc           four
# 64       177.8      66.5       55.5        2425        ohc           four
# 65       175.0      66.1       54.4        2670        ohc           four
# 66       175.0      66.1       54.4        2700        ohc           four
# 67       190.9      70.3       56.5        3515        ohc           five
# 68       190.9      70.3       58.7        3750        ohc           five
# 69       187.5      70.3       54.9        3495        ohc           five
# 70       202.6      71.7       56.3        3770        ohc           five
# 71       202.6      71.7       56.5        3740       ohcv          eight
# 72       180.3      70.5       50.8        3685       ohcv          eight
# 73       208.1      71.7       56.7        3900       ohcv          eight
# 74       199.2      72.0       55.4        3715       ohcv          eight
# 75       178.4      68.0       54.8        2910        ohc           four
# 76       157.3      64.4       50.8        1918        ohc           four
# 77       157.3      64.4       50.8        1944        ohc           four
# 78       157.3      64.4       50.8        2004        ohc           four
# 79       157.3      63.8       50.8        2145        ohc           four
# 80       173.0      65.4       49.4        2370        ohc           four
# 81       173.0      65.4       49.4        2328        ohc           four
# 82       173.2      66.3       50.2        2833        ohc           four
# 83       173.2      66.3       50.2        2921        ohc           four
# 84       173.2      66.3       50.2        2926        ohc           four
# 85       172.4      65.4       51.6        2365        ohc           four
# 86       172.4      65.4       51.6        2405        ohc           four
# 87       172.4      65.4       51.6        2403        ohc           four
# 88       172.4      65.4       51.6        2403        ohc           four
# 89       165.3      63.8       54.5        1889        ohc           four
# 90       165.3      63.8       54.5        2017        ohc           four
# 91       165.3      63.8       54.5        1918        ohc           four
# 92       165.3      63.8       54.5        1938        ohc           four
# 93       170.2      63.8       53.5        2024        ohc           four
# 94       165.3      63.8       54.5        1951        ohc           four
# 95       165.6      63.8       53.3        2028        ohc           four
# 96       165.3      63.8       54.5        1971        ohc           four
# 97       170.2      63.8       53.5        2037        ohc           four
# 98       162.4      63.8       53.3        2008        ohc           four
# 99       173.4      65.2       54.7        2324        ohc           four
# 100      173.4      65.2       54.7        2302        ohc           four
# 101      181.7      66.5       55.1        3095       ohcv            six
# 102      184.6      66.5       56.1        3296       ohcv            six
# 103      184.6      66.5       55.1        3060       ohcv            six
# 104      170.7      67.9       49.7        3071       ohcv            six
# 105      170.7      67.9       49.7        3139       ohcv            six
# 106      178.5      67.9       49.7        3139       ohcv            six
# 107      186.7      68.4       56.7        3020          l           four
# 108      186.7      68.4       56.7        3197          l           four
# 109      198.9      68.4       58.7        3230          l           four
# 110      198.9      68.4       58.7        3430          l           four
# 111      186.7      68.4       56.7        3075          l           four
# 112      186.7      68.4       56.7        3252          l           four
# 113      198.9      68.4       56.7        3285          l           four
# 114      198.9      68.4       58.7        3485          l           four
# 115      186.7      68.4       56.7        3075          l           four
# 116      186.7      68.4       56.7        3252          l           four
# 117      186.7      68.3       56.0        3130          l           four
# 118      157.3      63.8       50.8        1918        ohc           four
# 119      157.3      63.8       50.8        2128        ohc           four
# 120      157.3      63.8       50.6        1967        ohc           four
# 121      167.3      63.8       50.8        1989        ohc           four
# 122      167.3      63.8       50.8        2191        ohc           four
# 123      174.6      64.6       59.8        2535        ohc           four
# 124      173.2      66.3       50.2        2818        ohc           four
# 125      168.9      68.3       50.2        2778        ohc           four
# 126      168.9      65.0       51.6        2756       ohcf            six
# 127      168.9      65.0       51.6        2756       ohcf            six
# 128      168.9      65.0       51.6        2800       ohcf            six
# 129      175.7      72.3       50.5        3366      dohcv          eight
# 130      181.5      66.5       55.2        2579        ohc           four
# 131      176.8      66.6       50.5        2460        ohc           four
# 132      186.6      66.5       56.1        2658        ohc           four
# 133      186.6      66.5       56.1        2695        ohc           four
# 134      186.6      66.5       56.1        2707        ohc           four
# 135      186.6      66.5       56.1        2758        ohc           four
# 136      186.6      66.5       56.1        2808       dohc           four
# 137      186.6      66.5       56.1        2847       dohc           four
# 138      156.9      63.4       53.7        2050       ohcf           four
# 139      157.9      63.6       53.7        2120       ohcf           four
# 140      157.3      63.8       55.7        2240       ohcf           four
# 141      172.0      65.4       52.5        2145       ohcf           four
# 142      172.0      65.4       52.5        2190       ohcf           four
# 143      172.0      65.4       52.5        2340       ohcf           four
# 144      172.0      65.4       54.3        2385       ohcf           four
# 145      172.0      65.4       54.3        2510       ohcf           four
# 146      173.5      65.4       53.0        2290       ohcf           four
# 147      173.5      65.4       53.0        2455       ohcf           four
# 148      173.6      65.4       54.9        2420       ohcf           four
# 149      173.6      65.4       54.9        2650       ohcf           four
# 150      158.7      63.6       54.5        1985        ohc           four
# 151      158.7      63.6       54.5        2040        ohc           four
# 152      158.7      63.6       54.5        2015        ohc           four
# 153      169.7      63.6       59.1        2280        ohc           four
# 154      169.7      63.6       59.1        2290        ohc           four
# 155      169.7      63.6       59.1        3110        ohc           four
# 156      166.3      64.4       53.0        2081        ohc           four
# 157      166.3      64.4       52.8        2109        ohc           four
# 158      166.3      64.4       53.0        2275        ohc           four
# 159      166.3      64.4       52.8        2275        ohc           four
# 160      166.3      64.4       53.0        2094        ohc           four
# 161      166.3      64.4       52.8        2122        ohc           four
# 162      166.3      64.4       52.8        2140        ohc           four
# 163      168.7      64.0       52.6        2169        ohc           four
# 164      168.7      64.0       52.6        2204        ohc           four
# 165      168.7      64.0       52.6        2265       dohc           four
# 166      168.7      64.0       52.6        2300       dohc           four
# 167      176.2      65.6       52.0        2540        ohc           four
# 168      176.2      65.6       52.0        2536        ohc           four
# 169      176.2      65.6       52.0        2551        ohc           four
# 170      176.2      65.6       52.0        2679        ohc           four
# 171      176.2      65.6       52.0        2714        ohc           four
# 172      176.2      65.6       53.0        2975        ohc           four
# 173      175.6      66.5       54.9        2326        ohc           four
# 174      175.6      66.5       54.9        2480        ohc           four
# 175      175.6      66.5       53.9        2414        ohc           four
# 176      175.6      66.5       54.9        2414        ohc           four
# 177      175.6      66.5       53.9        2458        ohc           four
# 178      183.5      67.7       52.0        2976       dohc            six
# 179      183.5      67.7       52.0        3016       dohc            six
# 180      187.8      66.5       54.1        3131       dohc            six
# 181      187.8      66.5       54.1        3151       dohc            six
# 182      171.7      65.5       55.7        2261        ohc           four
# 183      171.7      65.5       55.7        2209        ohc           four
# 184      171.7      65.5       55.7        2264        ohc           four
# 185      171.7      65.5       55.7        2212        ohc           four
# 186      171.7      65.5       55.7        2275        ohc           four
# 187      171.7      65.5       55.7        2319        ohc           four
# 188      171.7      65.5       55.7        2300        ohc           four
# 189      159.3      64.2       55.6        2254        ohc           four
# 190      165.7      64.0       51.4        2221        ohc           four
# 191      180.2      66.9       55.1        2661        ohc           five
# 192      180.2      66.9       55.1        2579        ohc           four
# 193      183.1      66.9       55.1        2563        ohc           four
# 194      188.8      67.2       56.2        2912        ohc           four
# 195      188.8      67.2       57.5        3034        ohc           four
# 196      188.8      67.2       56.2        2935        ohc           four
# 197      188.8      67.2       57.5        3042        ohc           four
# 198      188.8      67.2       56.2        3045        ohc           four
# 199      188.8      67.2       57.5        3157        ohc           four
# 200      188.8      68.9       55.5        2952        ohc           four
# 201      188.8      68.8       55.5        3049        ohc           four
# 202      188.8      68.9       55.5        3012       ohcv            six
# 203      188.8      68.9       55.5        3217        ohc            six
# 204      188.8      68.9       55.5        3062        ohc           four
#
#      enginesize fuelsystem  boreratio  stroke  compressionratio  horsepower  \
# 0           130       mpfi       3.47   2.680              9.00         111
# 1           130       mpfi       3.47   2.680              9.00         111
# 2           152       mpfi       2.68   3.470              9.00         154
# 3           109       mpfi       3.19   3.400             10.00         102
# 4           136       mpfi       3.19   3.400              8.00         115
# 5           136       mpfi       3.19   3.400              8.50         110
# 6           136       mpfi       3.19   3.400              8.50         110
# 7           136       mpfi       3.19   3.400              8.50         110
# 8           131       mpfi       3.13   3.400              8.30         140
# ...
# 126         194       mpfi       3.74   2.900              9.50         207
# 127         194       mpfi       3.74   2.900              9.50         207
# 128         194       mpfi       3.74   2.900              9.50         207
# 129         203       mpfi       3.94   3.110             10.00         288
# 130         132       mpfi       3.46   3.900              8.70          90
# 131         132       mpfi       3.46   3.900              8.70          90
# 132         121       mpfi       3.54   3.070              9.31         110
# 133         121       mpfi       3.54   3.070              9.30         110
# 134         121       mpfi       2.54   2.070              9.30         110
# 135         121       mpfi       3.54   3.070              9.30         110
# 136         121       mpfi       3.54   3.070              9.00         160
# 137         121       mpfi       3.54   3.070              9.00         160
# 138          97       2bbl       3.62   2.360              9.00          69
# 139         108       2bbl       3.62   2.640              8.70          73
# 140         108       2bbl       3.62   2.640              8.70          73
# 141         108       2bbl       3.62   2.640              9.50          82
# 142         108       2bbl       3.62   2.640              9.50          82
# 143         108       mpfi       3.62   2.640              9.00          94
# 144         108       2bbl       3.62   2.640              9.00          82
# 145         108       mpfi       3.62   2.640              7.70         111
# 146         108       2bbl       3.62   2.640              9.00          82
# 147         108       mpfi       3.62   2.640              9.00          94
# 148         108       2bbl       3.62   2.640              9.00          82
# 149         108       mpfi       3.62   2.640              7.70         111
# 150          92       2bbl       3.05   3.030              9.00          62
# 151          92       2bbl       3.05   3.030              9.00          62
# 152          92       2bbl       3.05   3.030              9.00          62
# 153          92       2bbl       3.05   3.030              9.00          62
# 154          92       2bbl       3.05   3.030              9.00          62
# 155          92       2bbl       3.05   3.030              9.00          62
# 156          98       2bbl       3.19   3.030              9.00          70
# 157          98       2bbl       3.19   3.030              9.00          70
# 158         110        idi       3.27   3.350             22.50          56
# 159         110        idi       3.27   3.350             22.50          56
# 160          98       2bbl       3.19   3.030              9.00          70
# 161          98       2bbl       3.19   3.030              9.00          70
# 162          98       2bbl       3.19   3.030              9.00          70
# 163          98       2bbl       3.19   3.030              9.00          70
# 164          98       2bbl       3.19   3.030              9.00          70
# 165          98       mpfi       3.24   3.080              9.40         112
# 166          98       mpfi       3.24   3.080              9.40         112
# 167         146       mpfi       3.62   3.500              9.30         116
# 168         146       mpfi       3.62   3.500              9.30         116
# 169         146       mpfi       3.62   3.500              9.30         116
# 170         146       mpfi       3.62   3.500              9.30         116
# 171         146       mpfi       3.62   3.500              9.30         116
# 172         146       mpfi       3.62   3.500              9.30         116
# 173         122       mpfi       3.31   3.540              8.70          92
# 174         110        idi       3.27   3.350             22.50          73
# 175         122       mpfi       3.31   3.540              8.70          92
# 176         122       mpfi       3.31   3.540              8.70          92
# 177         122       mpfi       3.31   3.540              8.70          92
# 178         171       mpfi       3.27   3.350              9.30         161
# 179         171       mpfi       3.27   3.350              9.30         161
# 180         171       mpfi       3.27   3.350              9.20         156
# 181         161       mpfi       3.27   3.350              9.20         156
# 182          97        idi       3.01   3.400             23.00          52
# 183         109       mpfi       3.19   3.400              9.00          85
# 184          97        idi       3.01   3.400             23.00          52
# 185         109       mpfi       3.19   3.400              9.00          85
# 186         109       mpfi       3.19   3.400              9.00          85
# 187          97        idi       3.01   3.400             23.00          68
# 188         109       mpfi       3.19   3.400             10.00         100
# 189         109       mpfi       3.19   3.400              8.50          90
# 190         109       mpfi       3.19   3.400              8.50          90
# 191         136       mpfi       3.19   3.400              8.50         110
# 192          97        idi       3.01   3.400             23.00          68
# 193         109       mpfi       3.19   3.400              9.00          88
# 194         141       mpfi       3.78   3.150              9.50         114
# 195         141       mpfi       3.78   3.150              9.50         114
# 196         141       mpfi       3.78   3.150              9.50         114
# 197         141       mpfi       3.78   3.150              9.50         114
# 198         130       mpfi       3.62   3.150              7.50         162
# 199         130       mpfi       3.62   3.150              7.50         162
# 200         141       mpfi       3.78   3.150              9.50         114
# 201         141       mpfi       3.78   3.150              8.70         160
# 202         173       mpfi       3.58   2.870              8.80         134
# 203         145        idi       3.01   3.400             23.00         106
# 204         141       mpfi       3.78   3.150              9.50         114
#
#      peakrpm  citympg  highwaympg      price
# 0       5000       21          27  13495.000
# 1       5000       21          27  16500.000
# 2       5000       19          26  16500.000
# 3       5500       24          30  13950.000
# 4       5500       18          22  17450.000
# 5       5500       19          25  15250.000
# 6       5500       19          25  17710.000
# 7       5500       19          25  18920.000
# 8       5500       17          20  23875.000
# 9       5500       16          22  17859.167
# 10      5800       23          29  16430.000
# 11      5800       23          29  16925.000
# 12      4250       21          28  20970.000
# 13      4250       21          28  21105.000
# 14      4250       20          25  24565.000
# 15      5400       16          22  30760.000
# 16      5400       16          22  41315.000
# 17      5400       15          20  36880.000
# 18      5100       47          53   5151.000
# 19      5400       38          43   6295.000
# 20      5400       38          43   6575.000
# 21      5500       37          41   5572.000
# 22      5500       31          38   6377.000
# 23      5500       24          30   7957.000
# 24      5500       31          38   6229.000
# 25      5500       31          38   6692.000
# 26      5500       31          38   7609.000
# 27      5500       24          30   8558.000
# 28      5000       24          30   8921.000
# 29      5000       19          24  12964.000
# 30      4800       49          54   6479.000
# 31      6000       31          38   6855.000
# 32      5500       38          42   5399.000
# 33      6000       30          34   6529.000
# 34      6000       30          34   7129.000
# 35      6000       30          34   7295.000
# 36      6000       30          34   7295.000
# 37      5800       27          33   7895.000
# 38      5800       27          33   9095.000
# 39      5800       27          33   8845.000
# 40      5800       27          33  10295.000
# 41      5800       24          28  12945.000
# 42      5500       25          31  10345.000
# 43      4800       24          29   6785.000
# 44      5400       38          43   8916.500
# 45      5400       38          43   8916.500
# 46      5000       24          29  11048.000
# 47      4750       15          19  32250.000
# 48      4750       15          19  35550.000
# 49      5000       13          17  36000.000
# 50      5000       30          31   5195.000
# 51      5000       31          38   6095.000
# 52      5000       31          38   6795.000
# 53      5000       31          38   6695.000
# 54      5000       31          38   7395.000
# 55      6000       17          23  10945.000
# 56      6000       17          23  11845.000
# 57      6000       17          23  13645.000
# 58      6000       16          23  15645.000
# 59      4800       26          32   8845.000
# 60      4800       26          32   8495.000
# 61      4800       26          32  10595.000
# 62      4800       26          32  10245.000
# 63      4650       36          42  10795.000
# 64      4800       26          32  11245.000
# 65      5000       19          27  18280.000
# 66      4200       31          39  18344.000
# 67      4350       22          25  25552.000
# 68      4350       22          25  28248.000
# 69      4350       22          25  28176.000
# 70      4350       22          25  31600.000
# 71      4750       16          18  34184.000
# 72      4750       16          18  35056.000
# 73      4500       14          16  40960.000
# 74      4500       14          16  45400.000
# 75      5000       19          24  16503.000
# 76      5500       37          41   5389.000
# 77      5500       31          38   6189.000
# 78      5500       31          38   6669.000
# 79      5500       24          30   7689.000
# 80      5500       23          30   9959.000
# 81      5000       25          32   8499.000
# 82      5000       19          24  12629.000
# 83      5000       19          24  14869.000
# 84      5000       19          24  14489.000
# 85      5000       25          32   6989.000
# 86      5000       25          32   8189.000
# 87      5500       23          30   9279.000
# 88      5500       23          30   9279.000
# 89      5200       31          37   5499.000
# 90      4800       45          50   7099.000
# 91      5200       31          37   6649.000
# 92      5200       31          37   6849.000
# 93      5200       31          37   7349.000
# 94      5200       31          37   7299.000
# 95      5200       31          37   7799.000
# 96      5200       31          37   7499.000
# 97      5200       31          37   7999.000
# 98      5200       31          37   8249.000
# 99      5200       27          34   8949.000
# 100     5200       27          34   9549.000
# 101     5200       17          22  13499.000
# 102     5200       17          22  14399.000
# 103     5200       19          25  13499.000
# 104     5200       19          25  17199.000
# 105     5200       17          23  19699.000
# 106     5200       19          25  18399.000
# 107     5000       19          24  11900.000
# 108     4150       28          33  13200.000
# 109     5000       19          24  12440.000
# 110     4150       25          25  13860.000
# 111     5000       19          24  15580.000
# 112     4150       28          33  16900.000
# 113     5000       19          24  16695.000
# 114     4150       25          25  17075.000
# 115     5000       19          24  16630.000
# 116     4150       28          33  17950.000
# 117     5600       18          24  18150.000
# 118     5500       37          41   5572.000
# 119     5500       24          30   7957.000
# 120     5500       31          38   6229.000
# 121     5500       31          38   6692.000
# 122     5500       31          38   7609.000
# 123     5000       24          30   8921.000
# 124     5000       19          24  12764.000
# 125     5500       19          27  22018.000
# 126     5900       17          25  32528.000
# 127     5900       17          25  34028.000
# 128     5900       17          25  37028.000
# 129     5750       17          28  31400.500
# 130     5100       23          31   9295.000
# 131     5100       23          31   9895.000
# 132     5250       21          28  11850.000
# 133     5250       21          28  12170.000
# 134     5250       21          28  15040.000
# 135     5250       21          28  15510.000
# 136     5500       19          26  18150.000
# 137     5500       19          26  18620.000
# 138     4900       31          36   5118.000
# 139     4400       26          31   7053.000
# 140     4400       26          31   7603.000
# 141     4800       32          37   7126.000
# 142     4400       28          33   7775.000
# 143     5200       26          32   9960.000
# 144     4800       24          25   9233.000
# 145     4800       24          29  11259.000
# 146     4800       28          32   7463.000
# 147     5200       25          31  10198.000
# 148     4800       23          29   8013.000
# 149     4800       23          23  11694.000
# 150     4800       35          39   5348.000
# 151     4800       31          38   6338.000
# 152     4800       31          38   6488.000
# 153     4800       31          37   6918.000
# 154     4800       27          32   7898.000
# 155     4800       27          32   8778.000
# 156     4800       30          37   6938.000
# 157     4800       30          37   7198.000
# 158     4500       34          36   7898.000
# 159     4500       38          47   7788.000
# 160     4800       38          47   7738.000
# 161     4800       28          34   8358.000
# 162     4800       28          34   9258.000
# 163     4800       29          34   8058.000
# 164     4800       29          34   8238.000
# 165     6600       26          29   9298.000
# 166     6600       26          29   9538.000
# 167     4800       24          30   8449.000
# 168     4800       24          30   9639.000
# 169     4800       24          30   9989.000
# 170     4800       24          30  11199.000
# 171     4800       24          30  11549.000
# 172     4800       24          30  17669.000
# 173     4200       29          34   8948.000
# 174     4500       30          33  10698.000
# 175     4200       27          32   9988.000
# 176     4200       27          32  10898.000
# 177     4200       27          32  11248.000
# 178     5200       20          24  16558.000
# 179     5200       19          24  15998.000
# 180     5200       20          24  15690.000
# 181     5200       19          24  15750.000
# 182     4800       37          46   7775.000
# 183     5250       27          34   7975.000
# 184     4800       37          46   7995.000
# 185     5250       27          34   8195.000
# 186     5250       27          34   8495.000
# 187     4500       37          42   9495.000
# 188     5500       26          32   9995.000
# 189     5500       24          29  11595.000
# 190     5500       24          29   9980.000
# 191     5500       19          24  13295.000
# 192     4500       33          38  13845.000
# 193     5500       25          31  12290.000
# 194     5400       23          28  12940.000
# 195     5400       23          28  13415.000
# 196     5400       24          28  15985.000
# 197     5400       24          28  16515.000
# 198     5100       17          22  18420.000
# 199     5100       17          22  18950.000
# 200     5400       23          28  16845.000
# 201     5300       19          25  19045.000
# 202     5500       18          23  21485.000
# 203     4800       26          27  22470.000
# 204     5400       19          25  22625.000

# %%
cars['CompanyName'].value_counts()
# Out:
# CompanyName
# toyota         32
# mazda          17
# nissan         17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Nissan          1
# Name: count, dtype: int64

# %%
cars = cars.replace(to_replace ="maxda", value ="mazda")

# %% [markdown]
# # Visualizations

# %%
plt.title('Car Price Spread')
sns.boxplot(y=cars.price)
plt.show()
print(cars.price.describe())
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
plt.title('Car Price Distribution Plot')
sns.distplot(cars.price)
plt.show()

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Car Price Distribution Plot')
sns.distplot(cars.price)

plt.subplot(1,2,2)
plt.title('Car Price Spread')
sns.boxplot(y=cars.price)

plt.show()
print(cars.price.describe())
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
company  = cars['CompanyName'].value_counts()
company = company[:10,]

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=company.index, y=company.values, alpha=0.8)
plt.title('Company')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Company', fontsize=12)
plt.show()

# %%
company  = cars['CompanyName'].value_counts()
plt.figure(figsize=(10,5))
sns.barplot(x=company.index, y=company.values, alpha=0.8)
plt.title('Company')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Company', fontsize=12)
plt.xticks(rotation = 40)
plt.show()

# %%
def plot_count(x,fig):
    plt.subplot(4,2,fig)
    plt.title(x+' Histogram')
    sns.countplot(cars[x],palette=("magma"))
    plt.subplot(4,2,(fig+1))
    plt.title(x+' vs Price')
    sns.boxplot(x=cars[x], y=cars.price, palette=("magma"))
    
plt.figure(figsize=(15,20))

plot_count('enginelocation', 1)
plot_count('cylindernumber', 3)
plot_count('fuelsystem', 5)
plot_count('drivewheel', 7)

plt.tight_layout()

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(cars[x],cars['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)

plt.tight_layout()

# %%
#Binning the Car Companies based on avg prices of each Company.
cars['price'] = cars['price'].astype('int')
bins = [0,10000,20000,40000]
cars_bin=['Budget','Medium','Highend']
cars['carsrange_binned'] = pd.cut(cars['price'],bins,right=False,labels=cars_bin)
cars.head()
# Out:
#    symboling                   CarName  CompanyName fueltype aspiration  \
# 0          3        alfa-romero giulia  alfa-romero      gas        std
# 1          3       alfa-romero stelvio  alfa-romero      gas        std
# 2          1  alfa-romero Quadrifoglio  alfa-romero      gas        std
# 3          2                audi 100ls         audi      gas        std
# 4          2                audi 100ls         audi      gas        std
#
#   doornumber      carbody drivewheel enginelocation  wheelbase  carlength  \
# 0        two  convertible        rwd          front       88.6      168.8
# 1        two  convertible        rwd          front       88.6      168.8
# 2        two    hatchback        rwd          front       94.5      171.2
# 3       four        sedan        fwd          front       99.8      176.6
# 4       four        sedan        4wd          front       99.4      176.6
#
#    carwidth  carheight  curbweight enginetype cylindernumber  enginesize  \
# 0      64.1       48.8        2548       dohc           four         130
# 1      64.1       48.8        2548       dohc           four         130
# 2      65.5       52.4        2823       ohcv            six         152
# 3      66.2       54.3        2337        ohc           four         109
# 4      66.4       54.3        2824        ohc           five         136
#
#   fuelsystem  boreratio  stroke  compressionratio  horsepower  peakrpm  \
# 0       mpfi       3.47    2.68               9.0         111     5000
# 1       mpfi       3.47    2.68               9.0         111     5000
# 2       mpfi       2.68    3.47               9.0         154     5000
# 3       mpfi       3.19    3.40              10.0         102     5500
# 4       mpfi       3.19    3.40               8.0         115     5500
#
#    citympg  highwaympg  price carsrange_binned
# 0       21          27  13495           Medium
# 1       21          27  16500           Medium
# 2       19          26  16500           Medium
# 3       24          30  13950           Medium
# 4       18          22  17450           Medium

# %%
cars_new = cars[['price', 'fueltype', 'aspiration','carbody', 'drivewheel','wheelbase',
                  'curbweight', 'enginetype', 'cylindernumber', 'enginesize', 'boreratio','horsepower', 
                     'carlength','carwidth', 'carsrange_binned']]
cars_new.head()
sns.pairplot(cars_new)
plt.show()

# %%
c = ['#F1C40F', '#3498DB',"#9b59b6"]
labels = ['Budget','Medium','Highend']

patches, texts, pcts=plt.pie(cars['carsrange_binned'].value_counts(),labels =labels,colors=c, autopct='%.1f%%' ,
         wedgeprops={'linewidth': 5.0, 'edgecolor': 'white'},textprops={'size': '15', 'color':'black'})
plt.setp(texts, fontweight=700)

for i, color in enumerate(c):
    texts[i].set_color(color)

# %%
plt.figure(figsize=(15,10))
sns.countplot(x='carbody', data = cars,
              order=pd.value_counts(cars['carbody']).index, palette='BuGn_r')
plt.title('Number of Cars grouped by carbody', weight='bold')
plt.xlabel('Type', fontsize=12)
plt.ylabel('Count', fontsize=12)
# Out:
# Text(0, 0.5, 'Count')

# %%
fig, ax1 = plt.subplots(figsize=(20,10))
graph = sns.countplot(ax=ax1,x='carbody', data=cars, order=pd.value_counts(cars['carbody']).index, palette='BuGn_r')
graph.set_xticklabels(graph.get_xticklabels())
i=0
for p in graph.patches:
    height = p.get_height()
    graph.text(p.get_x()+p.get_width()/2., height + 0.1,
        cars['carbody'].value_counts()[i],ha="center")
    i += 1

plt.xlabel('Carbody TYpe', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.title('Number of Cars grouped by carbody', weight='bold')
# Out:
# Text(0.5, 1.0, 'Number of Cars grouped by carbody')

# %%
cars['carbody'].value_counts()
# Out:
# carbody
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
#df['adr'] = df['adr'].astype(float)
from numpy import mean
plt.figure(figsize=(15,10))
sns.barplot(x='carbody', y='citympg', hue='carsrange_binned', dodge=True, palette= 'PuBu_r', data=cars,estimator=mean,ci = None)
plt.title('Price Range grouped by Carbody and Fueltype', weight='bold')
plt.xlabel('Carbody', fontsize=12)
plt.ylabel('citympg', fontsize=12)
# Out:
# Text(0, 0.5, 'citympg')

# %%
from numpy import mean
plt.figure(figsize=(15,10))
sns.barplot(x='carbody', y='price',  palette= 'PuBu_r', data=cars,estimator=mean,ci = None)
plt.title('Price ', weight='bold')
plt.xlabel('Carbody', fontsize=12)
plt.ylabel('price', fontsize=12)
# Out:
# Text(0, 0.5, 'price')

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='carbody',order=pd.value_counts(cars['carbody']).index,hue='fueltype',data=cars)
plt.xticks(rotation = 40)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.kdeplot(cars.citympg, shade=True,color="r")
plt.xlim((0,54))
plt.title("Density plot on City Mileage")
plt.ylabel("Density")
plt.xlabel('City Mileage')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10,6))
fig = sns.kdeplot(cars['citympg'], shade=True, color="r")
fig = sns.kdeplot(cars['highwaympg'], shade=True, color="b")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.lineplot(data = cars, x = 'enginesize', y = 'horsepower', hue = 'carsrange_binned')
plt.title("Engine Size and Horsepower by Price Range")
plt.ylabel("Horse Power")
plt.xlabel('Engine Size')
plt.show()

# %%
cars.enginesize.hist(bins=10, alpha=0.5)
plt.title(" Histogram")
plt.xlabel("Engine Size")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Select only numeric columns
numeric_df = cars.select_dtypes(include=np.number)

# Calculate correlation matrix for numeric columns
corrmat = numeric_df.corr()

# Visualize the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(corrmat, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %%
numcorr = numeric_df.corr()
f, ax = plt.subplots(figsize = (19,1)) # set figure size
sns.heatmap(numcorr.sort_values(by = 'price', ascending = False).head(1), annot = True, fmt = ".2f")
plt.show()

# %%
numcorr['price'].sort_values(ascending = False).to_frame().plot.bar(color = 'blue')
plt.axhline(y = 0.5, color = 'r', linestyle = '-')
plt.title('Corrplot vs. Price')
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
list5 = []
for index,row in cars.iterrows():
    if len(row.doornumber) > 1:
        list5.append(w2n.word_to_num(row.doornumber))
    else:
        list5.append('4')

# %%
cars['doornumber_int'] = pd.Series(list5)

# %%
cars['doornumber_int'].unique()
# Out:
# array([2, 4])

# %%
cars.drop(['doornumber'],axis=1,inplace=True)

# %%
list6 = []
for index,row in cars.iterrows():
    if len(row.cylindernumber) > 1:
        list6.append(w2n.word_to_num(row.cylindernumber))
    else:
        list6.append('4')

# %%
cars['cylindernumber_int'] = pd.Series(list6)

# %%
cars['cylindernumber_int'].unique()
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8])

# %%
cars.drop(['cylindernumber'],axis=1,inplace=True)

# %% [markdown]
# # One Hot Encoding

# %%
#split the dependent variable and independent variable
cars_X =  cars.copy()
cars_X.drop(['price'],axis=1,inplace=True)
cars_y = cars['price']

# %%
cars_x= cars_X.iloc[:,:].values

# %%
type(cars_x)
# Out:
# numpy.ndarray

# %%
cars.head(1)
# Out:
#    symboling             CarName  CompanyName fueltype aspiration  \
# 0          3  alfa-romero giulia  alfa-romero      gas        std
#
#        carbody drivewheel enginelocation  wheelbase  carlength  carwidth  \
# 0  convertible        rwd          front       88.6      168.8      64.1
#
#    carheight  curbweight enginetype  enginesize fuelsystem  boreratio  stroke  \
# 0       48.8        2548       dohc         130       mpfi       3.47    2.68
#
#    compressionratio  horsepower  peakrpm  citympg  highwaympg  price  \
# 0               9.0         111     5000       21          27  13495
#
#   carsrange_binned  doornumber_int  cylindernumber_int
# 0           Medium               2                   4

# %%
list(cars_x[1,:])
# Out:
# [3,
#  'alfa-romero stelvio',
#  'alfa-romero',
#  'gas',
#  'std',
#  'convertible',
#  'rwd',
#  'front',
#  88.6,
#  168.8,
#  64.1,
#  48.8,
#  2548,
#  'dohc',
#  130,
#  'mpfi',
#  3.47,
#  2.68,
#  9.0,
#  111,
#  5000,
#  21,
#  27,
#  'Medium',
#  2,
#  4]

# %%
#list all the categorical variables
columns_ohe = [1,2,3,4,5,6,7,13,15,23]

# %%
list(cars_x[1,[1,2,3,4,5,6,7,13,15,23]])
# Out:
# ['alfa-romero stelvio',
#  'alfa-romero',
#  'gas',
#  'std',
#  'convertible',
#  'rwd',
#  'front',
#  'dohc',
#  'mpfi',
#  'Medium']

# %%
for num in tqdm(columns_ohe):
    dummy_ = pd.get_dummies(cars_x[:,num],sparse=True)
    if(num!=1):
        dummy = np.concatenate((dummy,dummy_),axis=1)
    else:
        dummy = dummy_
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 486.83it/s]

# %%
list(cars_x[1,:])
# Out:
# [3,
#  'alfa-romero stelvio',
#  'alfa-romero',
#  'gas',
#  'std',
#  'convertible',
#  'rwd',
#  'front',
#  88.6,
#  168.8,
#  64.1,
#  48.8,
#  2548,
#  'dohc',
#  130,
#  'mpfi',
#  3.47,
#  2.68,
#  9.0,
#  111,
#  5000,
#  21,
#  27,
#  'Medium',
#  2,
#  4]

# %%
cars_x = np.delete(cars_x,columns_ohe,1)

# %%
cars_x = np.concatenate((cars_x,dummy),axis=1)

# %%
list(cars_x[1,:])
# Out:
# [3,
#  88.6,
#  168.8,
#  64.1,
#  48.8,
#  2548,
#  130,
#  3.47,
#  2.68,
#  9.0,
#  111,
#  5000,
#  21,
#  27,
#  2,
#  4,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  True,
#  False,
#  False,
#  False,
#  False,
#  True]

# %% [markdown]
# # Data Splitting

# %%
np.random.seed(0)
number_of_samples = len(cars_x)
random_indices = np.random.permutation(number_of_samples)
num_training_samples = int(number_of_samples*0.75)
cars_x_train = cars_x[random_indices[:num_training_samples]]
cars_y_train=cars_y[random_indices[:num_training_samples]]
cars_x_validation=cars_x[random_indices[num_training_samples:]]
cars_y_validation=cars_y[random_indices[num_training_samples:]]

# %%
len(cars_x_train)
# Out:
# 153

# %%
len(cars_y_train)
# Out:
# 153

# %%
len(cars_x_validation)
# Out:
# 52

# %%
len(cars_y_validation)
# Out:
# 52

# %% [markdown]
# # Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Fit on training set only.
scaler.fit(cars_x_train)
# Apply transform to both thvfe training set and the test set.
cars_x_train = scaler.transform(cars_x_train)
cars_x_validation = scaler.transform(cars_x_validation)

# %%
cars_x_train.shape
# Out:
# (153, 210)

# %%
cars_x_validation.shape
# Out:
# (52, 210)

# %% [markdown]
# # Principal Component Analysis

# %%
from sklearn.decomposition import PCA
# Make an instance of the Model
pca = PCA(.95)
pca.fit(cars_x_train)
cars_x_train = pca.transform(cars_x_train)
cars_x_validation = pca.transform(cars_x_validation)

# %%
cars_x_train.shape
# Out:
# (153, 107)

# %%
cars_x_validation.shape
# Out:
# (52, 107)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(cars_x_train, cars_y_train)
cars_linear_train_predicted = model.predict(cars_x_train)
cars_linear_validation_predicted = model.predict(cars_x_validation)

# %%
from sklearn.metrics import r2_score,mean_squared_error
r2_score(cars_y_train, cars_linear_train_predicted)
# Out:
# 0.9893878785835334

# %%
r2_score(cars_y_validation, cars_linear_validation_predicted)
# Out:
# 0.9041222736518066

# %%
# The coefficients
#print("Coefficients: \n", model.coef_)
# The mean squared error
print("Training data -Mean squared error: %.2f" % mean_squared_error(cars_y_train, cars_linear_train_predicted))
print("Validation data - Mean squared error: %.2f" % mean_squared_error(cars_y_validation, cars_linear_validation_predicted))
# The coefficient of determination: 1 is perfect prediction
print("Training data Coefficient of determination: %.2f" % r2_score(cars_y_train, cars_linear_train_predicted))
print("Validation data Coefficient of determination: %.2f" % r2_score(cars_y_validation, cars_linear_validation_predicted))

# Plot outputs
plt.scatter(cars_y_train, cars_linear_train_predicted, color="black")
plt.scatter(cars_y_validation, cars_linear_validation_predicted, color="red")

#plt.plot(cars_y_validation, cars_linear_validation_predicted, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())
plt.title(" Dot Chart")
plt.xlabel("Actual Data")
plt.ylabel("Predicted Data")

plt.show()
# Out:
# Training data -Mean squared error: 632307.78
# Validation data - Mean squared error: 7121791.54
# Training data Coefficient of determination: 0.99
# Validation data Coefficient of determination: 0.90
